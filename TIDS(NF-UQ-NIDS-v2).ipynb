# %% [markdown]
# # 简介

# %% [markdown]
# 在这个Notebook里面，我将尝试利用现有技术实现一个基于Transformer的入侵检测系统并尽可能对其进行改进。首先，我将描述本架构的各个组成部分，在阐明其原理后对模型进行训练与评估，并在最后在相同问题下将该架构与其他架构进行对比。
#
# 以下是为训练此模型而导入的包：

# %%
# !pip install einops
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install imbalanced-learn
# !pip install Boruta
# !pip install rtdl_num_embeddings
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 621.3 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.4.0)
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 769.4 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.2.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.4.0)
# Installing collected packages: Boruta
# Successfully installed Boruta-0.3

# %% [markdown]
# 以下代码用于挂载google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 结构

# %% [markdown]
# ## 嵌入(Embedding)

# %% [markdown]
# 在该部分里，数值信息将被转换为可被Transformer识别的特征值并提供给后面的结构进行学习。

# %% [markdown]
# $$ReLU(Linear(Periodic(x_i)))$$

# %%
from torch import nn
import torch
from einops import rearrange

class Embedder(nn.Module):
    def __init__(self, dim, num_numerical_types=10):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(num_numerical_types, dim))
        self.biases = nn.Parameter(torch.randn(num_numerical_types, dim))

    def forward(self, x):
        x = rearrange(x, 'b n -> b n 1')
        return x * self.weights + self.biases

# %% [markdown]
# ## 位置编码(Positional Encoding)

# %% [markdown]
# 由于嵌入产生的信息并不带有位置信息，故需要在学习前将位置信息写入训练数据中。

# %% [markdown]
# $$PE(pos, 2i) = \sin(pos/1000^{2i/d\_model})$$
# $$PE(pos, 2i+1) = \cos(pos/1000^{2i/d\_model})$$

# %%
import torch
from torch import nn
from torch.autograd import Variable
from math import cos, sin, sqrt

class Positional_Encoder(nn.Module):
    def __init__(self, d_model, max_seq_len = 10):
        super().__init__()
        self.d_model = d_model

        pe = torch.zeros(max_seq_len, d_model)
        for pos in range(max_seq_len):
            for i in range(0,d_model,2):
                pe[pos,i] = sin(pos / (1000**(i/d_model)))
                pe[pos,i+1] = cos(pos / (1000**(i/d_model)))

        pe = pe.unsqueeze(0)
        self.register_buffer("pe",pe)

    def forward(self, x):
        x = x * sqrt(self.d_model)
        seq_len = x.size(1)
        y = Variable(self.pe[:,:seq_len],requires_grad=False).cuda()
        x = x + y
        return x

# %% [markdown]
# ## 注意力机制(Attention)

# %% [markdown]
# 本部分用于对输入向量进行处理以获取输入与输出间的对应关系。具体计算过程如下：

# %% [markdown]
# $$Attention(Q,K,V) = softmax\left(M+\frac{QK^T}{\sqrt{d_k}}\right)$$

# %%
import torch
from torch import nn
from torch.nn import functional as F
import math

def attention(q, k, v, d_k, mask=None, dropout=None):
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)
    if mask is not None:
      shape = scores.shape
      mask = get_mask(shape[0], 8, 10)
      scores = scores.masked_fill(mask == 0, -1e9)
    scores = F.softmax(scores, dim=-1)

    if dropout is not None:
        scores = dropout(scores)

    output = torch.matmul(scores, v)
    return output

class Multi_Head_Attention(nn.Module):
    def __init__(self, heads, d_model, dropout):
        super().__init__()
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads

        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)

    def forward(self, q, k, v, mask=None):

        bs = q.size(0)

        # perform linear operation and split into h heads
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)

        # transpose to get dimensions bs * h * sl * d_model
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)

        scores = attention(q, k, v, self.d_k, mask, self.dropout)

        # concatenate heads and put through final linear layer
        concat = scores.transpose(1,2).contiguous().view(bs, -1, self.d_model)

        output = self.out(concat)
        return output

# %% [markdown]
# ## 掩蔽(Masks)

# %% [markdown]
# 该部分用于对输入解码器(Decoder)的向量进行掩蔽来使得解码器能够根据上下文来推算结果。

# %%
import numpy as np
import torch
from torch.autograd import Variable

def get_mask(batch_size, heads, seq_size):
    mask_prob = 0.2
    mask_shape = (batch_size, heads, seq_size, seq_size)
    mask = torch.rand(mask_shape) > mask_prob
    return mask.cuda()

# %% [markdown]
# ## 前馈网络(Feed-Forward Network)

# %% [markdown]
# 该部分主要用于记忆注意力机制计算所产生的的关系。具体原理如下：

# %% [markdown]
# $$FFN(x) = \max(0,xW_1 + b_1)W_2 + b_2$$

# %%
from torch import nn
from torch.nn import functional as F

class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=1024, dropout = 0.1):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %% [markdown]
# ## 层归一化(Layer Norm)

# %% [markdown]
# 主要用于使不同范围的数据归一化到[0, 1]区间内，方便模型进行处理，具体原理如下：

# %% [markdown]
# $$LN(x) = \frac{x - \mu}{\delta}\cdot \alpha + \beta$$

# %%
from torch import nn
import torch

class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()

        self.size = d_model

        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        self.eps = eps
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) \
        / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

# %% [markdown]
# ## 编码器(Encoder)

# %% [markdown]
# 整个编码器由数个编码器嵌入器、数个编码器层与层归一化层组成。其中，一个编码器层由层归一化、注意力机制与前馈神经网络层组成，数据在经过这些处理后由dropout方法进行输出。

# %%
from torch import nn
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Encoder_Layer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = Multi_Head_Attention(heads, d_model, dropout)
        self.feedf = FeedForward(d_model).cuda()
        self.dropout_1 = nn.Dropout(dropout).cuda()
        self.dropout_2 = nn.Dropout(dropout).cuda()

    def forward(self, x, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.feedf(x2))
        return x

class Encoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.N = N
        self.embed = Embedder(d_model)
        self.pe = Positional_Encoder(d_model)
        self.layers = get_clones(Encoder_Layer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)

    def forward(self, src, mask = None):
        x = self.embed(src)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,mask)
        return self.norm(x)

# %% [markdown]
# ## 解码器

# %%
import torch
from torch import nn
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Decoder_Layer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.norm_3 = Norm(d_model)
        self.attn = Multi_Head_Attention(heads, d_model, dropout)
        self.msk_attn = Multi_Head_Attention(heads, d_model, dropout)
        self.feedf = FeedForward(d_model).cuda()
        self.dropout_1 = nn.Dropout(dropout).cuda()
        self.dropout_2 = nn.Dropout(dropout).cuda()
        self.dropout_3 = nn.Dropout(dropout).cuda()

    def forward(self, x, e_outputs, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.msk_attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.attn(x2,e_outputs,e_outputs,mask=None))
        x2 = self.norm_3(x)
        x = x +self.dropout_3(self.feedf(x2))
        return x

class Decoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.N = N
        self.embed = Embedder(d_model)
        self.pe = Positional_Encoder(d_model,1)
        self.layers = get_clones(Decoder_Layer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)

    def forward(self, trg, e_outputs, mask = None):
        x = self.embed(trg)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,e_outputs,mask)
        return self.norm(x)

# %% [markdown]
# ## 整体架构定义

# %%
import torch
from torch import nn

class Transformer(nn.Module):
    def __init__(self, trg_vocab, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.encoder = Encoder(d_model, N , heads, dropout)
        self.decoder = Decoder(d_model, N , heads, dropout)
        self.out = nn.Linear(10*d_model, trg_vocab)

    def forward(self, src, trg_mask=None):
        e_outputs = self.encoder(src, None)
        d_output = self.decoder(src, e_outputs, trg_mask)
        d_intermediate = d_output.view(d_output.size(0), -1)
        output = self.out(d_intermediate)
        output = torch.softmax(output,dim=1)
        return output

# %% [markdown]
# # 数据集与数据处理

# %% [markdown]
# ## NF-CEC-CIC-IDS2018-v2
# 下载数据集:https://rdm.uq.edu.au/files/ce5161d0-ef9c-11ed-827d-e762de186848
#
# 昆士兰大学Sarhan团队利用了CSE-CIC-IDS2018数据集的原始pcap文件生成了一个基于NetFlow的数据集，称为NF-CSE-CIC-IDS2018-v2。总的流量数量为18,893,708，其中2,258,141（11.95%）是攻击样本，16,635,567（88.05%）是良性样本。

# %% [markdown]
# ## 数据处理
# 本部分用于对数据进行预处理。由于本数据集的特殊性——正常流量远多于异常攻击流量，因此需要对数据进行下采样与SMOTE处理，前者用于限制数量较多的样本的数量，后者用于对数量较少的样本进行插值处理以增加其数量。

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.neighbors import NearestNeighbors
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import os

label_mapping = {}
directory_path = 'drive/MyDrive/Colab Notebooks/NF-UQ-NIDS-v2/data/'


class CICIDSDataset(Dataset):
    def __init__(self, data):
        self.features = data[:, :-3]  # Feature Columns
        self.at_type = data[:, -3]  # Attack Type Column
        self.labels = data[:, -2:]  # 1 Hot Encoded Label

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        feature = torch.from_numpy(self.features[idx]).float()
        label = self.labels[idx]
        at_type = self.at_type[idx]

        return feature, label, at_type


def data_process(data):
    # Feature selection by Boruta
    #np.int = np.int32
    #np.float = np.float64
    #np.bool = np.bool_
    #rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
    #boruta_selector = BorutaPy(rf, n_estimators='auto', verbose=2)

    # Undersampling & SMOTE
    max_class_size = 100000  # Size of all Classes for Undersampling
    class_counts = data['Attack_type'].value_counts()
    classes_to_undersample = class_counts[class_counts > max_class_size].index

    under_sampler = RandomUnderSampler(sampling_strategy={
        label: 7 * max_class_size if label == "Benign" else max_class_size if label in classes_to_undersample else
        class_counts[label] for label in np.unique(data['Attack_type'])
    }, random_state=42)
    nn_estimator = NearestNeighbors(n_neighbors=5, n_jobs=-1)
    smote = SMOTE(sampling_strategy={
        label: 7 * max_class_size if label == "Benign" else max_class_size for label in
        np.unique(data['Attack_type'])
    }, k_neighbors=nn_estimator, random_state=42)
    scaler = MinMaxScaler()

    features = data.drop(columns=['Label', 'Attack_type'])
    labels = data['Attack_type']

    # print('Features selecting...')
    # boruta_selector.fit(features.values, labels.values.ravel())
    # features = features[:, boruta_selector.support_]

    # PCA features extraction
    # print('Using PCA...')
    # scaler = StandardScaler()
    # features = np.nan_to_num(scaler.fit_transform(features))
    # pca = PCA(n_components=10, svd_solver='randomized')
    # features = pca.fit_transform(features)

    print('Under sampling...')
    sampled_features, sampled_labels = under_sampler.fit_resample(features, labels)
    print('Using SMOTE...')
    balanced_features, balanced_labels = smote.fit_resample(sampled_features, sampled_labels)
    scaled_data = scaler.fit_transform(balanced_features)

    data = pd.DataFrame(data=scaled_data)

    # Encode the actual Attack type for later analysis
    label_encoder = LabelEncoder()
    data['Attack_type'] = label_encoder.fit_transform(balanced_labels)
    label_mapping = dict(enumerate(label_encoder.classes_))

    # 1 Hot Encoding
    data['Attack_Label'] = data['Attack_type'].apply(
        lambda x: "Attack" if label_mapping[x] != "Benign" else "Benign")
    encoded_labels = pd.get_dummies(data['Attack_Label'], prefix='', prefix_sep='')
    data = pd.concat([data, encoded_labels], axis=1)
    data.drop("Attack_Label", axis=1, inplace=True)

    return data


def load_data():
    if os.path.exists(directory_path + "preprocessed/data.csv.gz"):
        print("Loading Preprocessed Data")
        data = pd.read_csv(directory_path + "preprocessed/data.csv.gz", compression='gzip' )
    else:
        chunk_size = 100000
        chunks = pd.read_csv(directory_path + 'NF-UQ-NIDS-v2.csv.gz', chunksize=chunk_size, compression='gzip')
        max_float64 = np.finfo(np.float64).max

        data = []
        mem = 0
        cnt = 1
        for chunk in chunks:
            chunk.drop(chunk.columns[[0, 2, -1]], axis=1, inplace=True)
            chunk.columns = chunk.columns.str.strip()
            chunk = chunk.dropna()

            chunk = chunk.rename(columns={'Attack': 'Attack_type'})
            feature_chunk = chunk.drop(columns=['Label', 'Attack_type'])
            numeric_columns = feature_chunk.select_dtypes(include=[np.number]).columns
            feature_chunk[numeric_columns] = np.minimum(feature_chunk[numeric_columns], max_float64)
            labels_chunk = chunk[['Label', 'Attack_type']]
            chunk = pd.concat([feature_chunk, labels_chunk], axis=1)
            mem += (chunk.memory_usage(deep=True)).sum() / (1024 * 1024 * 1024)
            data.append(chunk)

            # 当读取的数据集大于等于一定大小时，只对该数据块进行处理
            if mem >= 13:
                data = pd.concat(data, ignore_index=True)
                mem = 0    

                data = data_process(data)

                print(data['Attack'].value_counts())
                if not os.path.exists(directory_path + 'preprocessed'):
                    os.makedirs(directory_path + 'preprocessed')
                data.to_csv(directory_path + 'preprocessed/data' + str(cnt) + '.csv.gz', index=False, compression='gzip')
                cnt += 1
                print("saved")
                data = []
        else:
            data = pd.concat(data, ignore_index=True)
            data = data_process(data)

            print(data['Attack'].value_counts())
            if not os.path.exists(directory_path + 'preprocessed'):
                os.makedirs(directory_path + 'preprocessed')
            data.to_csv(directory_path + 'preprocessed/data' + str(cnt) + '.csv.gz', index=False, compression='gzip')
            cnt += 1
            print("saved")
            data = []

        data1 = pd.read_csv(directory_path + "preprocessed/data1.csv.gz", compression='gzip' )
        data2 = pd.read_csv(directory_path + "preprocessed/data2.csv.gz", compression='gzip' )
        data3 = pd.read_csv(directory_path + "preprocessed/data3.csv.gz", compression='gzip' )
        data = pd.concat([data1, data2, data3], ignore_index=True)

        features = data.drop(columns=['Attack_type', 'Attack', 'Benign'])
        labels = data[['Attack_type', 'Attack', 'Benign']]

        # PCA features extraction
        print('Using PCA...')
        scaler = StandardScaler()
        features = np.nan_to_num(scaler.fit_transform(features))
        pca = PCA(n_components=10, svd_solver='randomized')
        features = pd.DataFrame(pca.fit_transform(features))
        data = pd.concat([features, labels], axis=1)

        data.to_csv(directory_path + 'preprocessed/data.csv.gz', index=False, compression='gzip')
        del data1
        del data2
        del data3

    train_data, val_data = train_test_split(data, test_size=0.2, random_state=42)
    train_data, val_data = train_data.values, val_data.values

    return train_data, val_data


def get_data_loader(data, batch_size):
    cicids_dataset = CICIDSDataset(data)

    return DataLoader(cicids_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # 模型训练

# %% [markdown]
# 定义训练与评估函数

# %%
import torch
from torch import nn
from torch.nn import functional as F
import numpy as np
import time
import os
import torch
from torch.nn import functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, r2_score, \
    mean_squared_error, log_loss
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay


def plot_metrics(losses, accs, pres, recs, aucs, f1s):
    epochs = range(1, len(losses) + 1)
    metrics = {'Loss': losses, 'Accuracy': accs, 'Precision': pres, 'Recall': recs, 'AUC': aucs, 'F1 Score': f1s}
    categories = list(metrics.keys())
    num_categories = len(categories)
    num_subplots_per_row = 3
    num_rows = (num_categories + num_subplots_per_row - 1) // num_subplots_per_row
    
    plt.figure(figsize=(16, 4 * num_rows))  # 调整图表大小以适应多子图
    
    for i, metric_name in enumerate(categories, start=1):
        plt.subplot(num_rows, num_subplots_per_row, i)
        plt.plot(epochs, metrics[metric_name], marker='o')
        plt.title(metric_name)
        plt.xlabel('Epoch')
        plt.ylabel(metric_name.replace(" ", "\n"))  # 分行显示标签，如果标签中有空格的话
        plt.grid(True)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 自动调整子图间距，留出顶部标题空间
    plt.show()


def eval_model(model, loader):
    model.cuda()
    model.eval()
    losses = []
    correct = 0
    predictions = []
    targets = []

    with torch.no_grad():
        for data, target, _ in loader:
            data, target = data.to("cuda"), target.to("cuda")
            output = model(data)
            loss = F.cross_entropy(output, target).item()
            losses.append(loss)
            pred = torch.argmax(output, dim=1)
            correct += torch.eq(torch.argmax(output, dim=1),torch.argmax(target, dim=1)).cpu().sum().item()
            predictions.extend(pred.cpu().numpy())
            targets.extend(target.cpu().numpy())

    eval_loss = np.mean(losses)
    eval_acc = correct / len(loader.dataset)
    targets = torch.tensor(targets)

    # 计算精确率、召回率、F1 分数
    precision = precision_score(torch.argmax(targets, dim=1), predictions, average='macro')
    recall = recall_score(torch.argmax(targets, dim=1), predictions, average='macro')
    f1 = f1_score(torch.argmax(targets, dim=1), predictions, average='macro')

    # 计算 ROC 曲线和 AUC
    try:
        auc = roc_auc_score(torch.argmax(targets, dim=1), predictions, average='weighted')
    except ValueError:
        auc = None

    # 计算混淆矩阵
    conf_matrix = confusion_matrix(torch.argmax(targets, dim=1), predictions)

    # 计算 R-squared
    r_squared = r2_score(torch.argmax(targets, dim=1), predictions)

    # 计算均方误差
    mse = mean_squared_error(torch.argmax(targets, dim=1), predictions)

    # 计算对数损失
    try:
        logloss = log_loss(torch.argmax(targets, dim=1), predictions)
    except ValueError:
        logloss = None

    print("Loss:", eval_loss, "Accuracy:", eval_acc)
    print("Precision:", precision, "Recall:", recall, "F1 Score:", f1)
    print("AUC:", auc)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("R-squared:", r_squared)
    print("Mean Squared Error:", mse)
    print("Log Loss:", logloss)

    return eval_loss, eval_acc, precision, recall, f1, auc, r_squared, mse, logloss, conf_matrix


def train_model(model, opt, epochs, data, eval_data, path, print_every=100):
    model.cuda()

    pretrained_path = "drive/MyDrive/Colab Notebooks/NF-UQ-NIDS-v2/pretrained"
    top_acc = 0.

    if os.path.exists(pretrained_path + "/" + path):
        print("Loading Pretrained Model")
        state = torch.load(pretrained_path + "/" + path)
        model.load_state_dict(state["model_state_dict"])
        start_epoch = state["epoch"] + 1
        losses = state["ep_loss"]
        accs = state["ep_acc"]
        top_acc = max(accs)
        aucs = state["aucs"]
        f1s = state['f1s']
        recs = state['recs']
        pres = state['pres']
        conf_matrix = state['conf_matrix']
    else:
        start_epoch = 0
        losses, accs = [], []
        aucs = []
        f1s = []
        recs = []
        pres = []
        try:
            os.mkdir(pretrained_path)
        except OSError as error:
            pass

    start = time.time()
    temp = start

    for epoch in range(start_epoch, epochs):
        model.train()
        total_loss = 0
        for i, batch in enumerate(data):
            src, trg, _ = batch
            src, trg = src.cuda(), trg.cuda()

            if isinstance(model, Transformer):
                trg_mask = get_mask(128, 8, 10)
            else:
                trg_mask = None

            preds = model(src, trg_mask)
            opt.zero_grad()
            loss = F.cross_entropy(preds, trg)
            loss.backward()
            opt.step()

            total_loss += loss.data
            if (i + 1) % print_every == 0:
                loss_avg = total_loss / print_every
                print("time = %dm, epoch %d, iter = %d, loss = %.3f, \
                # %ds per %d iters" % ((time.time() - start) // 60,
                                     epoch + 1, i + 1, loss_avg, time.time() - temp,
                                     print_every))
                total_loss = 0
                temp = time.time()
        eval_loss, eval_acc, precision, recall, f1, auc, r_squared, mse, logloss, conf_matrix = eval_model(model, eval_data)
        losses.append(eval_loss)
        accs.append(eval_acc)
        pres.append(precision)
        recs.append(recall)
        aucs.append(auc)
        f1s.append(f1)
        
        plot_metrics(losses, accs, pres, recs, aucs, f1s)
        
        if eval_acc > top_acc:
            top_state = {
                "model_state_dict": model.state_dict(),
                "epoch": epoch
            }
            torch.save(top_state, pretrained_path + "/max_" + path)
        state = {
            'model_state_dict': model.state_dict(),
            'epoch': epoch,
            'ep_loss': losses,
            'ep_acc': accs,
            'pres': pres,
            'recs': recs,
            'f1s': f1s,
            'aucs': aucs,
            'conf_matrix': conf_matrix
        }
        torch.save(state, pretrained_path + "/" + path)

# %% [markdown]
# 设置参数并训练模型

# %%
import torch
from torch import nn
from torchsummary import summary


learning_rate = 1e-4
batch_size = 128
epochs = 30
dropout_rate = 0.5
d_model = 32
heads = 8
N = 6
trg_vocab = 2

train_data, val_data = load_data()

train_loader = get_data_loader(train_data, batch_size)
val_loader = get_data_loader(val_data, batch_size)

model = Transformer(trg_vocab, d_model, N, heads, dropout_rate)
save_path = "pretrained.pt"

for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)
model = model.to("cuda:0")
summary(model, (10, ))

optim = torch.optim.RAdam(model.parameters(), lr=learning_rate)

train_model(model, optim, epochs, train_loader, val_loader, save_path)
# Out:
# Loading Preprocessed Data
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#           Embedder-1               [-1, 10, 32]               0
# Positional_Encoder-2               [-1, 10, 32]               0
#               Norm-3               [-1, 10, 32]              32
#             Linear-4               [-1, 10, 32]           1,056
#             Linear-5               [-1, 10, 32]           1,056
#             Linear-6               [-1, 10, 32]           1,056
#            Dropout-7            [-1, 8, 10, 10]               0
#             Linear-8               [-1, 10, 32]           1,056
# Multi_Head_Attention-9               [-1, 10, 32]               0
#           Dropout-10               [-1, 10, 32]               0
#              Norm-11               [-1, 10, 32]              32
#            Linear-12             [-1, 10, 1024]          33,792
#           Dropout-13             [-1, 10, 1024]               0
#            Linear-14               [-1, 10, 32]          32,800
#       FeedForward-15               [-1, 10, 32]               0
#           Dropout-16               [-1, 10, 32]               0
#     Encoder_Layer-17               [-1, 10, 32]               0
#              Norm-18               [-1, 10, 32]              32
#            Linear-19               [-1, 10, 32]           1,056
#            Linear-20               [-1, 10, 32]           1,056
#            Linear-21               [-1, 10, 32]           1,056
#           Dropout-22            [-1, 8, 10, 10]               0
#            Linear-23               [-1, 10, 32]           1,056
# Multi_Head_Attention-24               [-1, 10, 32]               0
#           Dropout-25               [-1, 10, 32]               0
#              Norm-26               [-1, 10, 32]              32
#            Linear-27             [-1, 10, 1024]          33,792
#           Dropout-28             [-1, 10, 1024]               0
#            Linear-29               [-1, 10, 32]          32,800
#       FeedForward-30               [-1, 10, 32]               0
#           Dropout-31               [-1, 10, 32]               0
#     Encoder_Layer-32               [-1, 10, 32]               0
#              Norm-33               [-1, 10, 32]              32
#            Linear-34               [-1, 10, 32]           1,056
#            Linear-35               [-1, 10, 32]           1,056
#            Linear-36               [-1, 10, 32]           1,056
#           Dropout-37            [-1, 8, 10, 10]               0
#            Linear-38               [-1, 10, 32]           1,056
# Multi_Head_Attention-39               [-1, 10, 32]               0
#           Dropout-40               [-1, 10, 32]               0
#              Norm-41               [-1, 10, 32]              32
#            Linear-42             [-1, 10, 1024]          33,792
#           Dropout-43             [-1, 10, 1024]               0
#            Linear-44               [-1, 10, 32]          32,800
#       FeedForward-45               [-1, 10, 32]               0
#           Dropout-46               [-1, 10, 32]               0
#     Encoder_Layer-47               [-1, 10, 32]               0
#              Norm-48               [-1, 10, 32]              32
#            Linear-49               [-1, 10, 32]           1,056
#            Linear-50               [-1, 10, 32]           1,056
#            Linear-51               [-1, 10, 32]           1,056
#           Dropout-52            [-1, 8, 10, 10]               0
#            Linear-53               [-1, 10, 32]           1,056
# Multi_Head_Attention-54               [-1, 10, 32]               0
#           Dropout-55               [-1, 10, 32]               0
#              Norm-56               [-1, 10, 32]              32
#            Linear-57             [-1, 10, 1024]          33,792
#           Dropout-58             [-1, 10, 1024]               0
#            Linear-59               [-1, 10, 32]          32,800
#       FeedForward-60               [-1, 10, 32]               0
#           Dropout-61               [-1, 10, 32]               0
#     Encoder_Layer-62               [-1, 10, 32]               0
#              Norm-63               [-1, 10, 32]              32
#            Linear-64               [-1, 10, 32]           1,056
#            Linear-65               [-1, 10, 32]           1,056
#            Linear-66               [-1, 10, 32]           1,056
#           Dropout-67            [-1, 8, 10, 10]               0
#            Linear-68               [-1, 10, 32]           1,056
# Multi_Head_Attention-69               [-1, 10, 32]               0
#           Dropout-70               [-1, 10, 32]               0
#              Norm-71               [-1, 10, 32]              32
#            Linear-72             [-1, 10, 1024]          33,792
#           Dropout-73             [-1, 10, 1024]               0
#            Linear-74               [-1, 10, 32]          32,800
#       FeedForward-75               [-1, 10, 32]               0
#           Dropout-76               [-1, 10, 32]               0
#     Encoder_Layer-77               [-1, 10, 32]               0
#              Norm-78               [-1, 10, 32]              32
#            Linear-79               [-1, 10, 32]           1,056
#            Linear-80               [-1, 10, 32]           1,056
#            Linear-81               [-1, 10, 32]           1,056
#           Dropout-82            [-1, 8, 10, 10]               0
#            Linear-83               [-1, 10, 32]           1,056
# Multi_Head_Attention-84               [-1, 10, 32]               0
#           Dropout-85               [-1, 10, 32]               0
#              Norm-86               [-1, 10, 32]              32
#            Linear-87             [-1, 10, 1024]          33,792
#           Dropout-88             [-1, 10, 1024]               0
#            Linear-89               [-1, 10, 32]          32,800
#       FeedForward-90               [-1, 10, 32]               0
#           Dropout-91               [-1, 10, 32]               0
#     Encoder_Layer-92               [-1, 10, 32]               0
#              Norm-93               [-1, 10, 32]              32
#           Encoder-94               [-1, 10, 32]               0
#          Embedder-95               [-1, 10, 32]               0
# Positional_Encoder-96               [-1, 10, 32]               0
#              Norm-97               [-1, 10, 32]              32
#            Linear-98               [-1, 10, 32]           1,056
#            Linear-99               [-1, 10, 32]           1,056
#           Linear-100               [-1, 10, 32]           1,056
#          Dropout-101            [-1, 8, 10, 10]               0
#           Linear-102               [-1, 10, 32]           1,056
# Multi_Head_Attention-103               [-1, 10, 32]               0
#          Dropout-104               [-1, 10, 32]               0
#             Norm-105               [-1, 10, 32]              32
#           Linear-106               [-1, 10, 32]           1,056
#           Linear-107               [-1, 10, 32]           1,056
#           Linear-108               [-1, 10, 32]           1,056
#          Dropout-109            [-1, 8, 10, 10]               0
#           Linear-110               [-1, 10, 32]           1,056
# Multi_Head_Attention-111               [-1, 10, 32]               0
#          Dropout-112               [-1, 10, 32]               0
#             Norm-113               [-1, 10, 32]              32
#           Linear-114             [-1, 10, 1024]          33,792
#          Dropout-115             [-1, 10, 1024]               0
#           Linear-116               [-1, 10, 32]          32,800
#      FeedForward-117               [-1, 10, 32]               0
#          Dropout-118               [-1, 10, 32]               0
#    Decoder_Layer-119               [-1, 10, 32]               0
#             Norm-120               [-1, 10, 32]              32
#           Linear-121               [-1, 10, 32]           1,056
#           Linear-122               [-1, 10, 32]           1,056
#           Linear-123               [-1, 10, 32]           1,056
#          Dropout-124            [-1, 8, 10, 10]               0
#           Linear-125               [-1, 10, 32]           1,056
# Multi_Head_Attention-126               [-1, 10, 32]               0
#          Dropout-127               [-1, 10, 32]               0
#             Norm-128               [-1, 10, 32]              32
#           Linear-129               [-1, 10, 32]           1,056
#           Linear-130               [-1, 10, 32]           1,056
#           Linear-131               [-1, 10, 32]           1,056
#          Dropout-132            [-1, 8, 10, 10]               0
#           Linear-133               [-1, 10, 32]           1,056
# Multi_Head_Attention-134               [-1, 10, 32]               0
#          Dropout-135               [-1, 10, 32]               0
#             Norm-136               [-1, 10, 32]              32
#           Linear-137             [-1, 10, 1024]          33,792
#          Dropout-138             [-1, 10, 1024]               0
#           Linear-139               [-1, 10, 32]          32,800
#      FeedForward-140               [-1, 10, 32]               0
#          Dropout-141               [-1, 10, 32]               0
#    Decoder_Layer-142               [-1, 10, 32]               0
#             Norm-143               [-1, 10, 32]              32
#           Linear-144               [-1, 10, 32]           1,056
#           Linear-145               [-1, 10, 32]           1,056
#           Linear-146               [-1, 10, 32]           1,056
#          Dropout-147            [-1, 8, 10, 10]               0
#           Linear-148               [-1, 10, 32]           1,056
# Multi_Head_Attention-149               [-1, 10, 32]               0
#          Dropout-150               [-1, 10, 32]               0
#             Norm-151               [-1, 10, 32]              32
#           Linear-152               [-1, 10, 32]           1,056
#           Linear-153               [-1, 10, 32]           1,056
#           Linear-154               [-1, 10, 32]           1,056
#          Dropout-155            [-1, 8, 10, 10]               0
#           Linear-156               [-1, 10, 32]           1,056
# Multi_Head_Attention-157               [-1, 10, 32]               0
#          Dropout-158               [-1, 10, 32]               0
#             Norm-159               [-1, 10, 32]              32
#           Linear-160             [-1, 10, 1024]          33,792
#          Dropout-161             [-1, 10, 1024]               0
#           Linear-162               [-1, 10, 32]          32,800
#      FeedForward-163               [-1, 10, 32]               0
#          Dropout-164               [-1, 10, 32]               0
#    Decoder_Layer-165               [-1, 10, 32]               0
#             Norm-166               [-1, 10, 32]              32
#           Linear-167               [-1, 10, 32]           1,056
#           Linear-168               [-1, 10, 32]           1,056
#           Linear-169               [-1, 10, 32]           1,056
#          Dropout-170            [-1, 8, 10, 10]               0
#           Linear-171               [-1, 10, 32]           1,056
# Multi_Head_Attention-172               [-1, 10, 32]               0
#          Dropout-173               [-1, 10, 32]               0
#             Norm-174               [-1, 10, 32]              32
#           Linear-175               [-1, 10, 32]           1,056
#           Linear-176               [-1, 10, 32]           1,056
#           Linear-177               [-1, 10, 32]           1,056
#          Dropout-178            [-1, 8, 10, 10]               0
#           Linear-179               [-1, 10, 32]           1,056
# Multi_Head_Attention-180               [-1, 10, 32]               0
#          Dropout-181               [-1, 10, 32]               0
#             Norm-182               [-1, 10, 32]              32
#           Linear-183             [-1, 10, 1024]          33,792
#          Dropout-184             [-1, 10, 1024]               0
#           Linear-185               [-1, 10, 32]          32,800
#      FeedForward-186               [-1, 10, 32]               0
#          Dropout-187               [-1, 10, 32]               0
#    Decoder_Layer-188               [-1, 10, 32]               0
#             Norm-189               [-1, 10, 32]              32
#           Linear-190               [-1, 10, 32]           1,056
#           Linear-191               [-1, 10, 32]           1,056
#           Linear-192               [-1, 10, 32]           1,056
#          Dropout-193            [-1, 8, 10, 10]               0
#           Linear-194               [-1, 10, 32]           1,056
# Multi_Head_Attention-195               [-1, 10, 32]               0
#          Dropout-196               [-1, 10, 32]               0
#             Norm-197               [-1, 10, 32]              32
#           Linear-198               [-1, 10, 32]           1,056
#           Linear-199               [-1, 10, 32]           1,056
#           Linear-200               [-1, 10, 32]           1,056
#          Dropout-201            [-1, 8, 10, 10]               0
#           Linear-202               [-1, 10, 32]           1,056
# Multi_Head_Attention-203               [-1, 10, 32]               0
#          Dropout-204               [-1, 10, 32]               0
#             Norm-205               [-1, 10, 32]              32
#           Linear-206             [-1, 10, 1024]          33,792
#          Dropout-207             [-1, 10, 1024]               0
#           Linear-208               [-1, 10, 32]          32,800
#      FeedForward-209               [-1, 10, 32]               0
#          Dropout-210               [-1, 10, 32]               0
#    Decoder_Layer-211               [-1, 10, 32]               0
#             Norm-212               [-1, 10, 32]              32
#           Linear-213               [-1, 10, 32]           1,056
#           Linear-214               [-1, 10, 32]           1,056
#           Linear-215               [-1, 10, 32]           1,056
#          Dropout-216            [-1, 8, 10, 10]               0
#           Linear-217               [-1, 10, 32]           1,056
# Multi_Head_Attention-218               [-1, 10, 32]               0
#          Dropout-219               [-1, 10, 32]               0
#             Norm-220               [-1, 10, 32]              32
#           Linear-221               [-1, 10, 32]           1,056
#           Linear-222               [-1, 10, 32]           1,056
#           Linear-223               [-1, 10, 32]           1,056
#          Dropout-224            [-1, 8, 10, 10]               0
#           Linear-225               [-1, 10, 32]           1,056
# Multi_Head_Attention-226               [-1, 10, 32]               0
#          Dropout-227               [-1, 10, 32]               0
#             Norm-228               [-1, 10, 32]              32
#           Linear-229             [-1, 10, 1024]          33,792
#          Dropout-230             [-1, 10, 1024]               0
#           Linear-231               [-1, 10, 32]          32,800
#      FeedForward-232               [-1, 10, 32]               0
#          Dropout-233               [-1, 10, 32]               0
#    Decoder_Layer-234               [-1, 10, 32]               0
#             Norm-235               [-1, 10, 32]              32
#          Decoder-236               [-1, 10, 32]               0
#           Linear-237                    [-1, 2]             642
# ================================================================
# Total params: 876,802
# Trainable params: 875,778
# Non-trainable params: 1,024
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.46
# Params size (MB): 3.34
# Estimated Total Size (MB): 5.80
# ----------------------------------------------------------------
# time = 0m, epoch 1, iter = 100, loss = 0.658,                 8s per 100 iters
# time = 0m, epoch 1, iter = 200, loss = 0.575,                 6s per 100 iters
# time = 0m, epoch 1, iter = 300, loss = 0.579,                 6s per 100 iters
# time = 0m, epoch 1, iter = 400, loss = 0.572,                 6s per 100 iters
# time = 0m, epoch 1, iter = 500, loss = 0.564,                 6s per 100 iters
# time = 0m, epoch 1, iter = 600, loss = 0.557,                 6s per 100 iters
# time = 0m, epoch 1, iter = 700, loss = 0.556,                 6s per 100 iters
# time = 0m, epoch 1, iter = 800, loss = 0.551,                 6s per 100 iters
# time = 1m, epoch 1, iter = 900, loss = 0.553,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1000, loss = 0.543,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1100, loss = 0.550,                 7s per 100 iters
# time = 1m, epoch 1, iter = 1200, loss = 0.541,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1300, loss = 0.541,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1400, loss = 0.542,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1500, loss = 0.538,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1600, loss = 0.537,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1700, loss = 0.532,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1800, loss = 0.530,                 6s per 100 iters
# time = 2m, epoch 1, iter = 1900, loss = 0.525,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2000, loss = 0.526,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2100, loss = 0.523,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2200, loss = 0.517,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2300, loss = 0.508,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2400, loss = 0.504,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2500, loss = 0.502,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2600, loss = 0.504,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2700, loss = 0.504,                 6s per 100 iters
# time = 3m, epoch 1, iter = 2800, loss = 0.496,                 5s per 100 iters
# time = 3m, epoch 1, iter = 2900, loss = 0.501,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3000, loss = 0.495,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3100, loss = 0.495,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3200, loss = 0.494,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3300, loss = 0.494,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3400, loss = 0.497,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3500, loss = 0.494,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3600, loss = 0.495,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3700, loss = 0.495,                 7s per 100 iters
# time = 4m, epoch 1, iter = 3800, loss = 0.492,                 5s per 100 iters
# time = 4m, epoch 1, iter = 3900, loss = 0.488,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4000, loss = 0.490,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4100, loss = 0.481,                 7s per 100 iters
# time = 4m, epoch 1, iter = 4200, loss = 0.489,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4300, loss = 0.483,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4400, loss = 0.485,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4500, loss = 0.482,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4600, loss = 0.485,                 5s per 100 iters
# time = 5m, epoch 1, iter = 4700, loss = 0.486,                 6s per 100 iters
# time = 5m, epoch 1, iter = 4800, loss = 0.482,                 6s per 100 iters
# time = 5m, epoch 1, iter = 4900, loss = 0.484,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5000, loss = 0.481,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5100, loss = 0.483,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5200, loss = 0.474,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5300, loss = 0.483,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5400, loss = 0.479,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5500, loss = 0.477,                 6s per 100 iters
# time = 6m, epoch 1, iter = 5600, loss = 0.472,                 5s per 100 iters
# time = 6m, epoch 1, iter = 5700, loss = 0.476,                 6s per 100 iters
# time = 6m, epoch 1, iter = 5800, loss = 0.475,                 5s per 100 iters
# time = 6m, epoch 1, iter = 5900, loss = 0.469,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6000, loss = 0.473,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6100, loss = 0.474,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6200, loss = 0.471,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6300, loss = 0.472,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6400, loss = 0.471,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6500, loss = 0.469,                 6s per 100 iters
# time = 7m, epoch 1, iter = 6600, loss = 0.469,                 6s per 100 iters
# time = 7m, epoch 1, iter = 6700, loss = 0.471,                 6s per 100 iters
# time = 7m, epoch 1, iter = 6800, loss = 0.465,                 6s per 100 iters
# time = 7m, epoch 1, iter = 6900, loss = 0.460,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7000, loss = 0.464,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7100, loss = 0.470,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7200, loss = 0.469,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7300, loss = 0.463,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7400, loss = 0.464,                 5s per 100 iters
# time = 8m, epoch 1, iter = 7500, loss = 0.464,                 6s per 100 iters
# time = 8m, epoch 1, iter = 7600, loss = 0.461,                 5s per 100 iters
# time = 8m, epoch 1, iter = 7700, loss = 0.462,                 6s per 100 iters
# time = 8m, epoch 1, iter = 7800, loss = 0.458,                 6s per 100 iters
# time = 8m, epoch 1, iter = 7900, loss = 0.459,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8000, loss = 0.461,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8100, loss = 0.457,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8200, loss = 0.462,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8300, loss = 0.453,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8400, loss = 0.456,                 6s per 100 iters
# time = 9m, epoch 1, iter = 8500, loss = 0.455,                 6s per 100 iters
# time = 9m, epoch 1, iter = 8600, loss = 0.456,                 6s per 100 iters
# time = 9m, epoch 1, iter = 8700, loss = 0.459,                 6s per 100 iters
# time = 9m, epoch 1, iter = 8800, loss = 0.455,                 6s per 100 iters
# time = 9m, epoch 1, iter = 8900, loss = 0.457,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9000, loss = 0.455,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9100, loss = 0.453,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9200, loss = 0.455,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9300, loss = 0.453,                 6s per 100 iters
# time = 10m, epoch 1, iter = 9400, loss = 0.448,                 6s per 100 iters
# time = 10m, epoch 1, iter = 9500, loss = 0.455,                 6s per 100 iters
# time = 10m, epoch 1, iter = 9600, loss = 0.449,                 6s per 100 iters
# time = 10m, epoch 1, iter = 9700, loss = 0.457,                 7s per 100 iters
# time = 10m, epoch 1, iter = 9800, loss = 0.455,                 6s per 100 iters
# time = 10m, epoch 1, iter = 9900, loss = 0.448,                 7s per 100 iters
# time = 10m, epoch 1, iter = 10000, loss = 0.450,                 6s per 100 iters
# time = 10m, epoch 1, iter = 10100, loss = 0.453,                 7s per 100 iters
# time = 10m, epoch 1, iter = 10200, loss = 0.448,                 5s per 100 iters
# time = 11m, epoch 1, iter = 10300, loss = 0.452,                 7s per 100 iters
# time = 11m, epoch 1, iter = 10400, loss = 0.448,                 6s per 100 iters
# time = 11m, epoch 1, iter = 10500, loss = 0.448,                 7s per 100 iters
# time = 11m, epoch 1, iter = 10600, loss = 0.445,                 6s per 100 iters
# time = 11m, epoch 1, iter = 10700, loss = 0.448,                 7s per 100 iters
# time = 11m, epoch 1, iter = 10800, loss = 0.445,                 6s per 100 iters
# time = 11m, epoch 1, iter = 10900, loss = 0.449,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11000, loss = 0.443,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11100, loss = 0.444,                 7s per 100 iters
# time = 12m, epoch 1, iter = 11200, loss = 0.444,                 6s per 100 iters
# time = 12m, epoch 1, iter = 11300, loss = 0.449,                 7s per 100 iters
# time = 12m, epoch 1, iter = 11400, loss = 0.444,                 6s per 100 iters
# time = 12m, epoch 1, iter = 11500, loss = 0.448,                 7s per 100 iters
# time = 12m, epoch 1, iter = 11600, loss = 0.447,                 6s per 100 iters
# time = 12m, epoch 1, iter = 11700, loss = 0.445,                 7s per 100 iters
# time = 12m, epoch 1, iter = 11800, loss = 0.444,                 6s per 100 iters
# time = 12m, epoch 1, iter = 11900, loss = 0.445,                 7s per 100 iters
# time = 12m, epoch 1, iter = 12000, loss = 0.447,                 5s per 100 iters
# time = 13m, epoch 1, iter = 12100, loss = 0.447,                 6s per 100 iters
# time = 13m, epoch 1, iter = 12200, loss = 0.446,                 5s per 100 iters
# time = 13m, epoch 1, iter = 12300, loss = 0.444,                 6s per 100 iters
# time = 13m, epoch 1, iter = 12400, loss = 0.445,                 5s per 100 iters
# time = 13m, epoch 1, iter = 12500, loss = 0.442,                 6s per 100 iters
# time = 13m, epoch 1, iter = 12600, loss = 0.441,                 5s per 100 iters
# time = 13m, epoch 1, iter = 12700, loss = 0.439,                 6s per 100 iters
# time = 13m, epoch 1, iter = 12800, loss = 0.443,                 5s per 100 iters
# time = 13m, epoch 1, iter = 12900, loss = 0.440,                 6s per 100 iters
# time = 13m, epoch 1, iter = 13000, loss = 0.445,                 5s per 100 iters
# time = 14m, epoch 1, iter = 13100, loss = 0.450,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13200, loss = 0.446,                 5s per 100 iters
# time = 14m, epoch 1, iter = 13300, loss = 0.447,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13400, loss = 0.440,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13500, loss = 0.437,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13600, loss = 0.444,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13700, loss = 0.441,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13800, loss = 0.440,                 6s per 100 iters
# time = 14m, epoch 1, iter = 13900, loss = 0.438,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14000, loss = 0.441,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14100, loss = 0.444,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14200, loss = 0.441,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14300, loss = 0.440,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14400, loss = 0.440,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14500, loss = 0.440,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14600, loss = 0.446,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14700, loss = 0.436,                 6s per 100 iters
# time = 15m, epoch 1, iter = 14800, loss = 0.442,                 6s per 100 iters
# time = 16m, epoch 1, iter = 14900, loss = 0.439,                 6s per 100 iters
# time = 16m, epoch 1, iter = 15000, loss = 0.438,                 6s per 100 iters
# time = 16m, epoch 1, iter = 15100, loss = 0.434,                 8s per 100 iters
# time = 16m, epoch 1, iter = 15200, loss = 0.439,                 6s per 100 iters
# time = 16m, epoch 1, iter = 15300, loss = 0.441,                 7s per 100 iters
# time = 16m, epoch 1, iter = 15400, loss = 0.444,                 6s per 100 iters
# time = 16m, epoch 1, iter = 15500, loss = 0.440,                 7s per 100 iters
# time = 16m, epoch 1, iter = 15600, loss = 0.432,                 6s per 100 iters
# time = 16m, epoch 1, iter = 15700, loss = 0.437,                 7s per 100 iters
# time = 17m, epoch 1, iter = 15800, loss = 0.441,                 6s per 100 iters
# time = 17m, epoch 1, iter = 15900, loss = 0.435,                 7s per 100 iters
# time = 17m, epoch 1, iter = 16000, loss = 0.438,                 6s per 100 iters
# time = 17m, epoch 1, iter = 16100, loss = 0.435,                 7s per 100 iters
# time = 17m, epoch 1, iter = 16200, loss = 0.440,                 6s per 100 iters
# time = 17m, epoch 1, iter = 16300, loss = 0.438,                 7s per 100 iters
# time = 17m, epoch 1, iter = 16400, loss = 0.437,                 6s per 100 iters
# time = 17m, epoch 1, iter = 16500, loss = 0.436,                 7s per 100 iters
# time = 17m, epoch 1, iter = 16600, loss = 0.438,                 5s per 100 iters
# time = 18m, epoch 1, iter = 16700, loss = 0.437,                 7s per 100 iters
# time = 18m, epoch 1, iter = 16800, loss = 0.436,                 6s per 100 iters
# time = 18m, epoch 1, iter = 16900, loss = 0.435,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17000, loss = 0.438,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17100, loss = 0.433,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17200, loss = 0.440,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17300, loss = 0.438,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17400, loss = 0.436,                 6s per 100 iters
# time = 18m, epoch 1, iter = 17500, loss = 0.434,                 6s per 100 iters
# time = 19m, epoch 1, iter = 17600, loss = 0.439,                 6s per 100 iters
# time = 19m, epoch 1, iter = 17700, loss = 0.438,                 6s per 100 iters
# time = 19m, epoch 1, iter = 17800, loss = 0.434,                 6s per 100 iters
# time = 19m, epoch 1, iter = 17900, loss = 0.429,                 6s per 100 iters
# time = 19m, epoch 1, iter = 18000, loss = 0.432,                 6s per 100 iters
# time = 19m, epoch 1, iter = 18100, loss = 0.434,                 6s per 100 iters
# time = 19m, epoch 1, iter = 18200, loss = 0.437,                 7s per 100 iters
# time = 19m, epoch 1, iter = 18300, loss = 0.433,                 6s per 100 iters
# time = 19m, epoch 1, iter = 18400, loss = 0.434,                 7s per 100 iters
# time = 20m, epoch 1, iter = 18500, loss = 0.431,                 6s per 100 iters
# time = 20m, epoch 1, iter = 18600, loss = 0.436,                 6s per 100 iters
# time = 20m, epoch 1, iter = 18700, loss = 0.442,                 6s per 100 iters
# time = 20m, epoch 1, iter = 18800, loss = 0.439,                 7s per 100 iters
# time = 20m, epoch 1, iter = 18900, loss = 0.436,                 6s per 100 iters
# time = 20m, epoch 1, iter = 19000, loss = 0.434,                 7s per 100 iters
# time = 20m, epoch 1, iter = 19100, loss = 0.434,                 6s per 100 iters
# time = 20m, epoch 1, iter = 19200, loss = 0.430,                 6s per 100 iters
# time = 20m, epoch 1, iter = 19300, loss = 0.434,                 6s per 100 iters
# time = 21m, epoch 1, iter = 19400, loss = 0.435,                 7s per 100 iters
# time = 21m, epoch 1, iter = 19500, loss = 0.430,                 6s per 100 iters
# time = 21m, epoch 1, iter = 19600, loss = 0.432,                 7s per 100 iters
# time = 21m, epoch 1, iter = 19700, loss = 0.433,                 6s per 100 iters
# time = 21m, epoch 1, iter = 19800, loss = 0.434,                 7s per 100 iters
# time = 21m, epoch 1, iter = 19900, loss = 0.434,                 6s per 100 iters
# time = 21m, epoch 1, iter = 20000, loss = 0.433,                 7s per 100 iters
# time = 21m, epoch 1, iter = 20100, loss = 0.439,                 6s per 100 iters
# time = 22m, epoch 1, iter = 20200, loss = 0.433,                 7s per 100 iters
# time = 22m, epoch 1, iter = 20300, loss = 0.430,                 7s per 100 iters
# time = 22m, epoch 1, iter = 20400, loss = 0.434,                 6s per 100 iters
# time = 22m, epoch 1, iter = 20500, loss = 0.432,                 6s per 100 iters
# time = 22m, epoch 1, iter = 20600, loss = 0.433,                 6s per 100 iters
# time = 22m, epoch 1, iter = 20700, loss = 0.429,                 7s per 100 iters
# time = 22m, epoch 1, iter = 20800, loss = 0.438,                 6s per 100 iters
# time = 22m, epoch 1, iter = 20900, loss = 0.433,                 7s per 100 iters
# time = 22m, epoch 1, iter = 21000, loss = 0.432,                 6s per 100 iters
# time = 23m, epoch 1, iter = 21100, loss = 0.437,                 7s per 100 iters
# time = 23m, epoch 1, iter = 21200, loss = 0.428,                 6s per 100 iters
# time = 23m, epoch 1, iter = 21300, loss = 0.437,                 7s per 100 iters
# time = 23m, epoch 1, iter = 21400, loss = 0.432,                 6s per 100 iters
# time = 23m, epoch 1, iter = 21500, loss = 0.433,                 7s per 100 iters
# time = 23m, epoch 1, iter = 21600, loss = 0.432,                 6s per 100 iters
# time = 23m, epoch 1, iter = 21700, loss = 0.435,                 7s per 100 iters
# time = 23m, epoch 1, iter = 21800, loss = 0.432,                 6s per 100 iters
# time = 23m, epoch 1, iter = 21900, loss = 0.433,                 7s per 100 iters
# time = 24m, epoch 1, iter = 22000, loss = 0.431,                 5s per 100 iters
# time = 24m, epoch 1, iter = 22100, loss = 0.432,                 7s per 100 iters
# time = 24m, epoch 1, iter = 22200, loss = 0.435,                 6s per 100 iters
# time = 24m, epoch 1, iter = 22300, loss = 0.430,                 7s per 100 iters
# time = 24m, epoch 1, iter = 22400, loss = 0.435,                 6s per 100 iters
# time = 24m, epoch 1, iter = 22500, loss = 0.435,                 7s per 100 iters
# time = 24m, epoch 1, iter = 22600, loss = 0.435,                 6s per 100 iters
# time = 24m, epoch 1, iter = 22700, loss = 0.436,                 7s per 100 iters
# time = 24m, epoch 1, iter = 22800, loss = 0.435,                 6s per 100 iters
# time = 25m, epoch 1, iter = 22900, loss = 0.437,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23000, loss = 0.437,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23100, loss = 0.432,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23200, loss = 0.436,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23300, loss = 0.435,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23400, loss = 0.435,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23500, loss = 0.437,                 6s per 100 iters
# time = 25m, epoch 1, iter = 23600, loss = 0.431,                 7s per 100 iters
# time = 25m, epoch 1, iter = 23700, loss = 0.435,                 6s per 100 iters
# time = 26m, epoch 1, iter = 23800, loss = 0.432,                 7s per 100 iters
# time = 26m, epoch 1, iter = 23900, loss = 0.431,                 6s per 100 iters
# time = 26m, epoch 1, iter = 24000, loss = 0.432,                 7s per 100 iters
# time = 26m, epoch 1, iter = 24100, loss = 0.430,                 6s per 100 iters
# time = 26m, epoch 1, iter = 24200, loss = 0.433,                 6s per 100 iters
# time = 26m, epoch 1, iter = 24300, loss = 0.433,                 5s per 100 iters
# time = 26m, epoch 1, iter = 24400, loss = 0.433,                 6s per 100 iters
# time = 26m, epoch 1, iter = 24500, loss = 0.428,                 5s per 100 iters
# time = 26m, epoch 1, iter = 24600, loss = 0.431,                 6s per 100 iters
# time = 27m, epoch 1, iter = 24700, loss = 0.432,                 5s per 100 iters
# time = 27m, epoch 1, iter = 24800, loss = 0.436,                 6s per 100 iters
# time = 27m, epoch 1, iter = 24900, loss = 0.431,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25000, loss = 0.428,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25100, loss = 0.429,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25200, loss = 0.430,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25300, loss = 0.434,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25400, loss = 0.431,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25500, loss = 0.435,                 6s per 100 iters
# time = 27m, epoch 1, iter = 25600, loss = 0.427,                 6s per 100 iters
# time = 28m, epoch 1, iter = 25700, loss = 0.426,                 6s per 100 iters
# time = 28m, epoch 1, iter = 25800, loss = 0.433,                 5s per 100 iters
# time = 28m, epoch 1, iter = 25900, loss = 0.433,                 6s per 100 iters
# time = 28m, epoch 1, iter = 26000, loss = 0.431,                 5s per 100 iters
# time = 28m, epoch 1, iter = 26100, loss = 0.429,                 6s per 100 iters
# time = 28m, epoch 1, iter = 26200, loss = 0.432,                 5s per 100 iters
# time = 28m, epoch 1, iter = 26300, loss = 0.431,                 6s per 100 iters
# time = 28m, epoch 1, iter = 26400, loss = 0.430,                 5s per 100 iters
# time = 28m, epoch 1, iter = 26500, loss = 0.426,                 6s per 100 iters
# time = 29m, epoch 1, iter = 26600, loss = 0.432,                 5s per 100 iters
# time = 29m, epoch 1, iter = 26700, loss = 0.433,                 6s per 100 iters
# time = 29m, epoch 1, iter = 26800, loss = 0.435,                 5s per 100 iters
# time = 29m, epoch 1, iter = 26900, loss = 0.438,                 6s per 100 iters
# time = 29m, epoch 1, iter = 27000, loss = 0.433,                 5s per 100 iters
# time = 29m, epoch 1, iter = 27100, loss = 0.431,                 6s per 100 iters
# time = 29m, epoch 1, iter = 27200, loss = 0.426,                 5s per 100 iters
# time = 29m, epoch 1, iter = 27300, loss = 0.433,                 6s per 100 iters
# time = 29m, epoch 1, iter = 27400, loss = 0.424,                 5s per 100 iters
# time = 29m, epoch 1, iter = 27500, loss = 0.430,                 6s per 100 iters
# time = 30m, epoch 1, iter = 27600, loss = 0.433,                 5s per 100 iters
# time = 30m, epoch 1, iter = 27700, loss = 0.434,                 6s per 100 iters
# time = 30m, epoch 1, iter = 27800, loss = 0.432,                 5s per 100 iters
# time = 30m, epoch 1, iter = 27900, loss = 0.431,                 6s per 100 iters
# time = 30m, epoch 1, iter = 28000, loss = 0.429,                 5s per 100 iters
# time = 30m, epoch 1, iter = 28100, loss = 0.431,                 6s per 100 iters
# time = 30m, epoch 1, iter = 28200, loss = 0.431,                 5s per 100 iters
# time = 30m, epoch 1, iter = 28300, loss = 0.432,                 6s per 100 iters
# time = 30m, epoch 1, iter = 28400, loss = 0.429,                 5s per 100 iters
# time = 31m, epoch 1, iter = 28500, loss = 0.429,                 6s per 100 iters
# time = 31m, epoch 1, iter = 28600, loss = 0.429,                 5s per 100 iters
# time = 31m, epoch 1, iter = 28700, loss = 0.430,                 6s per 100 iters
# time = 31m, epoch 1, iter = 28800, loss = 0.428,                 6s per 100 iters
# time = 31m, epoch 1, iter = 28900, loss = 0.430,                 6s per 100 iters
# time = 31m, epoch 1, iter = 29000, loss = 0.431,                 6s per 100 iters
# time = 31m, epoch 1, iter = 29100, loss = 0.428,                 5s per 100 iters
# time = 31m, epoch 1, iter = 29200, loss = 0.432,                 6s per 100 iters
# time = 31m, epoch 1, iter = 29300, loss = 0.427,                 5s per 100 iters
# time = 31m, epoch 1, iter = 29400, loss = 0.428,                 6s per 100 iters
# time = 32m, epoch 1, iter = 29500, loss = 0.428,                 5s per 100 iters
# time = 32m, epoch 1, iter = 29600, loss = 0.426,                 6s per 100 iters
# time = 32m, epoch 1, iter = 29700, loss = 0.430,                 5s per 100 iters
# time = 32m, epoch 1, iter = 29800, loss = 0.430,                 6s per 100 iters
# time = 32m, epoch 1, iter = 29900, loss = 0.429,                 5s per 100 iters
# time = 32m, epoch 1, iter = 30000, loss = 0.429,                 6s per 100 iters
# time = 32m, epoch 1, iter = 30100, loss = 0.431,                 5s per 100 iters
# time = 32m, epoch 1, iter = 30200, loss = 0.432,                 6s per 100 iters
# time = 32m, epoch 1, iter = 30300, loss = 0.427,                 5s per 100 iters
# time = 32m, epoch 1, iter = 30400, loss = 0.430,                 6s per 100 iters
# time = 33m, epoch 1, iter = 30500, loss = 0.428,                 5s per 100 iters
# time = 33m, epoch 1, iter = 30600, loss = 0.427,                 6s per 100 iters
# time = 33m, epoch 1, iter = 30700, loss = 0.425,                 5s per 100 iters
# time = 33m, epoch 1, iter = 30800, loss = 0.430,                 6s per 100 iters
# time = 33m, epoch 1, iter = 30900, loss = 0.431,                 5s per 100 iters
# time = 33m, epoch 1, iter = 31000, loss = 0.430,                 6s per 100 iters
# time = 33m, epoch 1, iter = 31100, loss = 0.429,                 5s per 100 iters
# time = 33m, epoch 1, iter = 31200, loss = 0.427,                 6s per 100 iters
# time = 33m, epoch 1, iter = 31300, loss = 0.426,                 6s per 100 iters
# time = 34m, epoch 1, iter = 31400, loss = 0.433,                 5s per 100 iters
# time = 34m, epoch 1, iter = 31500, loss = 0.428,                 6s per 100 iters
# time = 34m, epoch 1, iter = 31600, loss = 0.427,                 5s per 100 iters
# time = 34m, epoch 1, iter = 31700, loss = 0.426,                 6s per 100 iters
# time = 34m, epoch 1, iter = 31800, loss = 0.426,                 5s per 100 iters
# time = 34m, epoch 1, iter = 31900, loss = 0.429,                 6s per 100 iters
# time = 34m, epoch 1, iter = 32000, loss = 0.426,                 5s per 100 iters
# time = 34m, epoch 1, iter = 32100, loss = 0.425,                 6s per 100 iters
# time = 34m, epoch 1, iter = 32200, loss = 0.427,                 5s per 100 iters
# time = 34m, epoch 1, iter = 32300, loss = 0.429,                 6s per 100 iters
# time = 35m, epoch 1, iter = 32400, loss = 0.429,                 5s per 100 iters
# time = 35m, epoch 1, iter = 32500, loss = 0.427,                 6s per 100 iters
# time = 35m, epoch 1, iter = 32600, loss = 0.427,                 5s per 100 iters
# time = 35m, epoch 1, iter = 32700, loss = 0.428,                 6s per 100 iters
# time = 35m, epoch 1, iter = 32800, loss = 0.428,                 5s per 100 iters
# time = 35m, epoch 1, iter = 32900, loss = 0.428,                 6s per 100 iters
# time = 35m, epoch 1, iter = 33000, loss = 0.429,                 5s per 100 iters
# time = 35m, epoch 1, iter = 33100, loss = 0.427,                 6s per 100 iters
# time = 35m, epoch 1, iter = 33200, loss = 0.428,                 5s per 100 iters
# time = 35m, epoch 1, iter = 33300, loss = 0.428,                 6s per 100 iters
# time = 36m, epoch 1, iter = 33400, loss = 0.424,                 5s per 100 iters
# time = 36m, epoch 1, iter = 33500, loss = 0.427,                 6s per 100 iters
# time = 36m, epoch 1, iter = 33600, loss = 0.431,                 6s per 100 iters
# time = 36m, epoch 1, iter = 33700, loss = 0.430,                 5s per 100 iters
# time = 36m, epoch 1, iter = 33800, loss = 0.425,                 6s per 100 iters
# time = 36m, epoch 1, iter = 33900, loss = 0.431,                 5s per 100 iters
# time = 36m, epoch 1, iter = 34000, loss = 0.423,                 6s per 100 iters
# time = 36m, epoch 1, iter = 34100, loss = 0.429,                 5s per 100 iters
# time = 36m, epoch 1, iter = 34200, loss = 0.429,                 6s per 100 iters
# time = 36m, epoch 1, iter = 34300, loss = 0.428,                 5s per 100 iters
# time = 37m, epoch 1, iter = 34400, loss = 0.424,                 6s per 100 iters
# time = 37m, epoch 1, iter = 34500, loss = 0.430,                 5s per 100 iters
# time = 37m, epoch 1, iter = 34600, loss = 0.430,                 6s per 100 iters
# time = 37m, epoch 1, iter = 34700, loss = 0.427,                 5s per 100 iters
# time = 37m, epoch 1, iter = 34800, loss = 0.427,                 6s per 100 iters
# time = 37m, epoch 1, iter = 34900, loss = 0.430,                 5s per 100 iters
# time = 37m, epoch 1, iter = 35000, loss = 0.427,                 6s per 100 iters
# time = 37m, epoch 1, iter = 35100, loss = 0.426,                 5s per 100 iters
# time = 37m, epoch 1, iter = 35200, loss = 0.427,                 6s per 100 iters
# time = 38m, epoch 1, iter = 35300, loss = 0.427,                 6s per 100 iters
# time = 38m, epoch 1, iter = 35400, loss = 0.427,                 7s per 100 iters
# time = 38m, epoch 1, iter = 35500, loss = 0.426,                 6s per 100 iters
# time = 38m, epoch 1, iter = 35600, loss = 0.429,                 7s per 100 iters
# time = 38m, epoch 1, iter = 35700, loss = 0.428,                 6s per 100 iters
# time = 38m, epoch 1, iter = 35800, loss = 0.431,                 6s per 100 iters
# time = 38m, epoch 1, iter = 35900, loss = 0.425,                 6s per 100 iters
# time = 38m, epoch 1, iter = 36000, loss = 0.426,                 7s per 100 iters
# time = 38m, epoch 1, iter = 36100, loss = 0.428,                 5s per 100 iters
# time = 39m, epoch 1, iter = 36200, loss = 0.425,                 7s per 100 iters
# time = 39m, epoch 1, iter = 36300, loss = 0.427,                 6s per 100 iters
# time = 39m, epoch 1, iter = 36400, loss = 0.431,                 7s per 100 iters
# time = 39m, epoch 1, iter = 36500, loss = 0.424,                 6s per 100 iters
# time = 39m, epoch 1, iter = 36600, loss = 0.423,                 7s per 100 iters
# time = 39m, epoch 1, iter = 36700, loss = 0.430,                 6s per 100 iters
# time = 39m, epoch 1, iter = 36800, loss = 0.426,                 7s per 100 iters
# time = 39m, epoch 1, iter = 36900, loss = 0.426,                 6s per 100 iters
# time = 39m, epoch 1, iter = 37000, loss = 0.425,                 7s per 100 iters
# time = 40m, epoch 1, iter = 37100, loss = 0.423,                 6s per 100 iters
# time = 40m, epoch 1, iter = 37200, loss = 0.426,                 6s per 100 iters
# time = 40m, epoch 1, iter = 37300, loss = 0.424,                 6s per 100 iters
# time = 40m, epoch 1, iter = 37400, loss = 0.426,                 7s per 100 iters
# time = 40m, epoch 1, iter = 37500, loss = 0.425,                 6s per 100 iters
# time = 40m, epoch 1, iter = 37600, loss = 0.425,                 7s per 100 iters
# time = 40m, epoch 1, iter = 37700, loss = 0.425,                 6s per 100 iters
# time = 40m, epoch 1, iter = 37800, loss = 0.427,                 7s per 100 iters
# time = 40m, epoch 1, iter = 37900, loss = 0.425,                 6s per 100 iters
# time = 40m, epoch 1, iter = 38000, loss = 0.424,                 6s per 100 iters
# time = 41m, epoch 1, iter = 38100, loss = 0.427,                 6s per 100 iters
# time = 41m, epoch 1, iter = 38200, loss = 0.426,                 6s per 100 iters
# time = 41m, epoch 1, iter = 38300, loss = 0.427,                 5s per 100 iters
# time = 41m, epoch 1, iter = 38400, loss = 0.423,                 7s per 100 iters
# time = 41m, epoch 1, iter = 38500, loss = 0.425,                 5s per 100 iters
# time = 41m, epoch 1, iter = 38600, loss = 0.427,                 6s per 100 iters
# time = 41m, epoch 1, iter = 38700, loss = 0.430,                 5s per 100 iters
# time = 41m, epoch 1, iter = 38800, loss = 0.425,                 7s per 100 iters
# time = 41m, epoch 1, iter = 38900, loss = 0.425,                 5s per 100 iters
# time = 42m, epoch 1, iter = 39000, loss = 0.427,                 7s per 100 iters
# time = 42m, epoch 1, iter = 39100, loss = 0.423,                 6s per 100 iters
# time = 42m, epoch 1, iter = 39200, loss = 0.428,                 7s per 100 iters
# time = 42m, epoch 1, iter = 39300, loss = 0.426,                 6s per 100 iters
# time = 42m, epoch 1, iter = 39400, loss = 0.424,                 6s per 100 iters
# ...
# time = 155m, epoch 3, iter = 37400, loss = 0.397,                 6s per 100 iters
# time = 156m, epoch 3, iter = 37500, loss = 0.394,                 6s per 100 iters
# time = 156m, epoch 3, iter = 37600, loss = 0.399,                 6s per 100 iters
# time = 156m, epoch 3, iter = 37700, loss = 0.398,                 6s per 100 iters
# time = 156m, epoch 3, iter = 37800, loss = 0.396,                 6s per 100 iters
# time = 156m, epoch 3, iter = 37900, loss = 0.403,                 6s per 100 iters
# time = 156m, epoch 3, iter = 38000, loss = 0.394,                 7s per 100 iters
# time = 156m, epoch 3, iter = 38100, loss = 0.393,                 5s per 100 iters
# time = 156m, epoch 3, iter = 38200, loss = 0.397,                 6s per 100 iters
# time = 156m, epoch 3, iter = 38300, loss = 0.395,                 6s per 100 iters
# time = 157m, epoch 3, iter = 38400, loss = 0.396,                 7s per 100 iters
# time = 157m, epoch 3, iter = 38500, loss = 0.396,                 6s per 100 iters
# time = 157m, epoch 3, iter = 38600, loss = 0.398,                 7s per 100 iters
# time = 157m, epoch 3, iter = 38700, loss = 0.397,                 6s per 100 iters
# time = 157m, epoch 3, iter = 38800, loss = 0.397,                 6s per 100 iters
# time = 157m, epoch 3, iter = 38900, loss = 0.397,                 5s per 100 iters
# time = 157m, epoch 3, iter = 39000, loss = 0.394,                 7s per 100 iters
# time = 157m, epoch 3, iter = 39100, loss = 0.396,                 6s per 100 iters
# time = 157m, epoch 3, iter = 39200, loss = 0.397,                 7s per 100 iters
# time = 157m, epoch 3, iter = 39300, loss = 0.396,                 6s per 100 iters
# time = 158m, epoch 3, iter = 39400, loss = 0.400,                 7s per 100 iters
# time = 158m, epoch 3, iter = 39500, loss = 0.397,                 6s per 100 iters
# time = 158m, epoch 3, iter = 39600, loss = 0.398,                 7s per 100 iters
# time = 158m, epoch 3, iter = 39700, loss = 0.398,                 6s per 100 iters
# time = 158m, epoch 3, iter = 39800, loss = 0.398,                 7s per 100 iters
# time = 158m, epoch 3, iter = 39900, loss = 0.398,                 6s per 100 iters
# time = 158m, epoch 3, iter = 40000, loss = 0.395,                 7s per 100 iters
# time = 158m, epoch 3, iter = 40100, loss = 0.399,                 6s per 100 iters
# time = 158m, epoch 3, iter = 40200, loss = 0.399,                 6s per 100 iters
# time = 159m, epoch 3, iter = 40300, loss = 0.399,                 5s per 100 iters
# time = 159m, epoch 3, iter = 40400, loss = 0.396,                 7s per 100 iters
# time = 159m, epoch 3, iter = 40500, loss = 0.397,                 6s per 100 iters
# time = 159m, epoch 3, iter = 40600, loss = 0.395,                 6s per 100 iters
# time = 159m, epoch 3, iter = 40700, loss = 0.400,                 6s per 100 iters
# time = 159m, epoch 3, iter = 40800, loss = 0.394,                 7s per 100 iters
# time = 159m, epoch 3, iter = 40900, loss = 0.398,                 6s per 100 iters
# time = 159m, epoch 3, iter = 41000, loss = 0.400,                 7s per 100 iters
# time = 159m, epoch 3, iter = 41100, loss = 0.396,                 6s per 100 iters
# time = 160m, epoch 3, iter = 41200, loss = 0.396,                 7s per 100 iters
# time = 160m, epoch 3, iter = 41300, loss = 0.399,                 6s per 100 iters
# time = 160m, epoch 3, iter = 41400, loss = 0.399,                 7s per 100 iters
# time = 160m, epoch 3, iter = 41500, loss = 0.396,                 6s per 100 iters
# time = 160m, epoch 3, iter = 41600, loss = 0.395,                 7s per 100 iters
# time = 160m, epoch 3, iter = 41700, loss = 0.396,                 6s per 100 iters
# time = 160m, epoch 3, iter = 41800, loss = 0.397,                 7s per 100 iters
# time = 160m, epoch 3, iter = 41900, loss = 0.396,                 6s per 100 iters
# time = 160m, epoch 3, iter = 42000, loss = 0.393,                 7s per 100 iters
# time = 161m, epoch 3, iter = 42100, loss = 0.398,                 6s per 100 iters
# time = 161m, epoch 3, iter = 42200, loss = 0.394,                 6s per 100 iters
# time = 161m, epoch 3, iter = 42300, loss = 0.395,                 5s per 100 iters
# time = 161m, epoch 3, iter = 42400, loss = 0.399,                 7s per 100 iters
# time = 161m, epoch 3, iter = 42500, loss = 0.395,                 6s per 100 iters
# time = 161m, epoch 3, iter = 42600, loss = 0.400,                 6s per 100 iters
# time = 161m, epoch 3, iter = 42700, loss = 0.395,                 5s per 100 iters
# time = 161m, epoch 3, iter = 42800, loss = 0.396,                 6s per 100 iters
# time = 161m, epoch 3, iter = 42900, loss = 0.400,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43000, loss = 0.394,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43100, loss = 0.398,                 5s per 100 iters
# time = 162m, epoch 3, iter = 43200, loss = 0.396,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43300, loss = 0.397,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43400, loss = 0.400,                 7s per 100 iters
# time = 162m, epoch 3, iter = 43500, loss = 0.398,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43600, loss = 0.397,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43700, loss = 0.399,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43800, loss = 0.396,                 6s per 100 iters
# time = 162m, epoch 3, iter = 43900, loss = 0.397,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44000, loss = 0.399,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44100, loss = 0.397,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44200, loss = 0.398,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44300, loss = 0.397,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44400, loss = 0.396,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44500, loss = 0.393,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44600, loss = 0.400,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44700, loss = 0.399,                 6s per 100 iters
# time = 163m, epoch 3, iter = 44800, loss = 0.397,                 6s per 100 iters
# time = 164m, epoch 3, iter = 44900, loss = 0.397,                 7s per 100 iters
# time = 164m, epoch 3, iter = 45000, loss = 0.392,                 6s per 100 iters
# time = 164m, epoch 3, iter = 45100, loss = 0.396,                 7s per 100 iters
# time = 164m, epoch 3, iter = 45200, loss = 0.397,                 5s per 100 iters
# time = 164m, epoch 3, iter = 45300, loss = 0.396,                 7s per 100 iters
# time = 164m, epoch 3, iter = 45400, loss = 0.394,                 6s per 100 iters
# time = 164m, epoch 3, iter = 45500, loss = 0.395,                 6s per 100 iters
# time = 164m, epoch 3, iter = 45600, loss = 0.398,                 5s per 100 iters
# time = 164m, epoch 3, iter = 45700, loss = 0.398,                 6s per 100 iters
# time = 165m, epoch 3, iter = 45800, loss = 0.398,                 6s per 100 iters
# time = 165m, epoch 3, iter = 45900, loss = 0.395,                 7s per 100 iters
# time = 165m, epoch 3, iter = 46000, loss = 0.394,                 6s per 100 iters
# time = 165m, epoch 3, iter = 46100, loss = 0.397,                 7s per 100 iters
# time = 165m, epoch 3, iter = 46200, loss = 0.394,                 6s per 100 iters
# time = 165m, epoch 3, iter = 46300, loss = 0.396,                 7s per 100 iters
# time = 165m, epoch 3, iter = 46400, loss = 0.394,                 6s per 100 iters
# time = 165m, epoch 3, iter = 46500, loss = 0.394,                 6s per 100 iters
# time = 165m, epoch 3, iter = 46600, loss = 0.396,                 6s per 100 iters
# time = 166m, epoch 3, iter = 46700, loss = 0.393,                 7s per 100 iters
# time = 166m, epoch 3, iter = 46800, loss = 0.395,                 6s per 100 iters
# time = 166m, epoch 3, iter = 46900, loss = 0.396,                 6s per 100 iters
# time = 166m, epoch 3, iter = 47000, loss = 0.398,                 5s per 100 iters
# time = 166m, epoch 3, iter = 47100, loss = 0.397,                 6s per 100 iters
# time = 166m, epoch 3, iter = 47200, loss = 0.395,                 6s per 100 iters
# time = 166m, epoch 3, iter = 47300, loss = 0.399,                 6s per 100 iters
# time = 166m, epoch 3, iter = 47400, loss = 0.395,                 6s per 100 iters
# time = 166m, epoch 3, iter = 47500, loss = 0.395,                 6s per 100 iters
# time = 167m, epoch 3, iter = 47600, loss = 0.394,                 5s per 100 iters
# time = 167m, epoch 3, iter = 47700, loss = 0.397,                 6s per 100 iters
# time = 167m, epoch 3, iter = 47800, loss = 0.398,                 5s per 100 iters
# time = 167m, epoch 3, iter = 47900, loss = 0.397,                 6s per 100 iters
# time = 167m, epoch 3, iter = 48000, loss = 0.399,                 5s per 100 iters
# time = 167m, epoch 3, iter = 48100, loss = 0.395,                 6s per 100 iters
# time = 167m, epoch 3, iter = 48200, loss = 0.399,                 6s per 100 iters
# time = 167m, epoch 3, iter = 48300, loss = 0.393,                 6s per 100 iters
# time = 167m, epoch 3, iter = 48400, loss = 0.395,                 5s per 100 iters
# time = 167m, epoch 3, iter = 48500, loss = 0.396,                 6s per 100 iters
# time = 168m, epoch 3, iter = 48600, loss = 0.393,                 5s per 100 iters
# time = 168m, epoch 3, iter = 48700, loss = 0.396,                 6s per 100 iters
# time = 168m, epoch 3, iter = 48800, loss = 0.398,                 6s per 100 iters
# time = 168m, epoch 3, iter = 48900, loss = 0.394,                 6s per 100 iters
# time = 168m, epoch 3, iter = 49000, loss = 0.400,                 6s per 100 iters
# time = 168m, epoch 3, iter = 49100, loss = 0.398,                 7s per 100 iters
# time = 168m, epoch 3, iter = 49200, loss = 0.393,                 6s per 100 iters
# time = 168m, epoch 3, iter = 49300, loss = 0.398,                 7s per 100 iters
# time = 168m, epoch 3, iter = 49400, loss = 0.395,                 6s per 100 iters
# time = 169m, epoch 3, iter = 49500, loss = 0.393,                 7s per 100 iters
# time = 169m, epoch 3, iter = 49600, loss = 0.398,                 5s per 100 iters
# time = 169m, epoch 3, iter = 49700, loss = 0.395,                 6s per 100 iters
# time = 169m, epoch 3, iter = 49800, loss = 0.398,                 5s per 100 iters
# time = 169m, epoch 3, iter = 49900, loss = 0.396,                 6s per 100 iters
# time = 169m, epoch 3, iter = 50000, loss = 0.397,                 6s per 100 iters
# time = 169m, epoch 3, iter = 50100, loss = 0.397,                 6s per 100 iters
# time = 169m, epoch 3, iter = 50200, loss = 0.394,                 5s per 100 iters
# time = 169m, epoch 3, iter = 50300, loss = 0.397,                 6s per 100 iters
# time = 170m, epoch 3, iter = 50400, loss = 0.393,                 5s per 100 iters
# time = 170m, epoch 3, iter = 50500, loss = 0.394,                 6s per 100 iters
# time = 170m, epoch 3, iter = 50600, loss = 0.394,                 6s per 100 iters
# Loss: 0.387912054382072 Accuracy: 92.12697530864197
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-788374985b93> in <cell line: 31>()
#      29 optim = torch.optim.RAdam(model.parameters(), lr=learning_rate)
#      30
# ---> 31 train_model(model, optim, epochs, train_loader, val_loader, save_path)
#
# <ipython-input-13-c20ade44ba43> in train_model(model, opt, epochs, data, eval_data, path, print_every)
#      59                 trg_mask = None
#      60
# ---> 61             preds = model(src, trg_mask)
#      62             opt.zero_grad()
#      63             loss = F.cross_entropy(preds, trg)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-11-55bca8855b89> in forward(self, src, trg_mask)
#      11     def forward(self, src, trg_mask=None):
#      12         e_outputs = self.encoder(src, None)
# ---> 13         d_output = self.decoder(src, e_outputs, trg_mask)
#      14         d_intermediate = d_output.view(d_output.size(0), -1)
#      15         output = self.out(d_intermediate)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-10-18a2c8d7f16a> in forward(self, trg, e_outputs, mask)
#      41         x = self.pe(x)
#      42         for i in range(self.N):
# ---> 43             x = self.layers[i](x,e_outputs,mask)
#      44         return self.norm(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-10-18a2c8d7f16a> in forward(self, x, e_outputs, mask)
#      23         x = x + self.dropout_1(self.msk_attn(x2,x2,x2,mask))
#      24         x2 = self.norm_2(x)
# ---> 25         x = x + self.dropout_2(self.attn(x2,e_outputs,e_outputs,mask=None))
#      26         x2 = self.norm_3(x)
#      27         x = x +self.dropout_3(self.feedf(x2))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-5-57802950c5a0> in forward(self, q, k, v, mask)
#      45         v = v.transpose(1,2)
#      46
# ---> 47         scores = attention(q, k, v, self.d_k, mask, self.dropout)
#      48
#      49         # concatenate heads and put through final linear layer
#
# <ipython-input-5-57802950c5a0> in attention(q, k, v, d_k, mask, dropout)
#      15         scores = dropout(scores)
#      16
# ---> 17     output = torch.matmul(scores, v)
#      18     return output
#      19
#
# KeyboardInterrupt:
