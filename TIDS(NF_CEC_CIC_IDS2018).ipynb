# %% [markdown]
# # 简介

# %% [markdown]
# 在这个Notebook里面，我将尝试利用现有技术实现一个基于Transformer的入侵检测系统并尽可能对其进行改进。首先，我将描述本架构的各个组成部分，在阐明其原理后对模型进行训练与评估，并在最后在相同问题下将该架构与其他架构进行对比。
#
# 以下是为训练此模型而导入的包：

# %%
# !pip install einops
# !pip install rtdl_num_embeddings
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)

# %% [markdown]
# 以下代码用于挂载google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 结构

# %% [markdown]
# ## 嵌入(Embedding)

# %% [markdown]
# 在该部分里，数值信息将被转换为可被Transformer识别的特征值并提供给后面的结构进行学习。

# %% [markdown]
# $ReLU(Linear(Periodic(x_i)))$

# %%
from torch import nn
import torch
# from einops import rearrange
from rtdl_num_embeddings import PeriodicEmbeddings

class Embedder(nn.Module):
    def __init__(self, dim, num_numerical_types=10):
        super().__init__()
        # self.weights = nn.Parameter(torch.randn(num_numerical_types, dim))
        # self.biases = nn.Parameter(torch.randn(num_numerical_types, dim))
        self.embeddings = PeriodicEmbeddings(num_numerical_types, dim, lite=False)

    def forward(self, x):
        # x = rearrange(x, 'b n -> b n 1')
        # return x * self.weights + self.biases
        return self.embeddings(x)

# %% [markdown]
# ## 位置编码(Positional Encoding)

# %% [markdown]
# 由于嵌入产生的信息并不带有位置信息，故需要在学习前将位置信息写入训练数据中。

# %% [markdown]
# $$PE(pos, 2i) = \sin(pos/1000^{2i/d\_model})$$
# $$PE(pos, 2i+1) = \cos(pos/1000^{2i/d\_model})$$

# %%
import torch
from torch import nn
from torch.autograd import Variable
from math import cos, sin, sqrt

class Positional_Encoder(nn.Module):
    def __init__(self, d_model, max_seq_len = 10):
        super().__init__()
        self.d_model = d_model

        pe = torch.zeros(max_seq_len, d_model)
        for pos in range(max_seq_len):
            for i in range(0,d_model,2):
                pe[pos,i] = sin(pos / (1000**(i/d_model)))
                pe[pos,i+1] = cos(pos / (1000**(i/d_model)))

        pe = pe.unsqueeze(0)
        self.register_buffer("pe",pe)

    def forward(self, x):
        x = x * sqrt(self.d_model)
        seq_len = x.size(1)
        y = Variable(self.pe[:,:seq_len],requires_grad=False).cuda()
        x = x + y
        return x

# %% [markdown]
# ## 注意力机制(Attention)

# %% [markdown]
# 本部分用于对输入向量进行处理以获取输入与输出间的对应关系。具体计算过程如下：

# %% [markdown]
# $$Attention(Q,K,V) = softmax\left(M+\frac{QK^T}{\sqrt{d_k}}\right)$$

# %%
import torch
from torch import nn
from torch.nn import functional as F
import math

def attention(q, k, v, d_k, mask=None, dropout=None):
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    scores = F.softmax(scores, dim=-1)

    if dropout is not None:
        scores = dropout(scores)

    output = torch.matmul(scores, v)
    return output

class Multi_Head_Attention(nn.Module):
    def __init__(self, heads, d_model, dropout):
        super().__init__()
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads

        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)

    def forward(self, q, k, v, mask=None):

        bs = q.size(0)

        # perform linear operation and split into h heads
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)

        # transpose to get dimensions bs * h * sl * d_model
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)

        scores = attention(q, k, v, self.d_k, mask, self.dropout)

        # concatenate heads and put through final linear layer
        concat = scores.transpose(1,2).contiguous().view(bs, -1, self.d_model)

        output = self.out(concat)
        return output

# %% [markdown]
# ## 掩蔽(Masks)

# %% [markdown]
# 该部分用于对输入解码器(Decoder)的向量进行掩蔽来使得解码器能够根据上下文来推算结果。

# %%
import numpy as np
import torch
from torch.autograd import Variable

def get_mask(batch_size, heads, seq_size):
    mask_prob = 0.2
    mask = torch.rand((batch_size, heads, seq_size, seq_size)) > mask_prob
    return mask.cuda()

# %% [markdown]
# ## 前馈网络(Feed-Forward Network)

# %% [markdown]
# 该部分主要用于记忆注意力机制计算所产生的的关系。具体原理如下：

# %% [markdown]
# $$FFN(x) = \max(0,xW_1 + b_1)W_2 + b_2$$

# %%
from torch import nn
from torch.nn import functional as F

class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=1024, dropout = 0.1):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %% [markdown]
# ## 层归一化(Layer Norm)

# %% [markdown]
# 主要用于使不同范围的数据归一化到[0, 1]区间内，方便模型进行处理，具体原理如下：

# %% [markdown]
# $$LN(x) = \frac{x - \mu}{\delta}\cdot \alpha + \beta$$

# %%
from torch import nn
import torch

class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()

        self.size = d_model

        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        self.eps = eps
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) \
        / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

# %% [markdown]
# ## 编码器(Encoder)

# %% [markdown]
# 整个编码器由数个编码器嵌入器、数个编码器层与层归一化层组成。其中，一个编码器层由层归一化、注意力机制与前馈神经网络层组成，数据在经过这些处理后由dropout方法进行输出。

# %%
from torch import nn
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Encoder_Layer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = Multi_Head_Attention(heads, d_model, dropout)
        self.feedf = FeedForward(d_model).cuda()
        self.dropout_1 = nn.Dropout(dropout).cuda()
        self.dropout_2 = nn.Dropout(dropout).cuda()

    def forward(self, x, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.feedf(x2))
        return x

class Encoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.N = N
        self.embed = Embedder(d_model)
        self.pe = Positional_Encoder(d_model)
        self.layers = get_clones(Encoder_Layer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)

    def forward(self, src, mask = None):
        x = self.embed(src)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,mask)
        return self.norm(x)

# %% [markdown]
# ## 解码器

# %%
import torch
from torch import nn
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Decoder_Layer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.norm_3 = Norm(d_model)
        self.attn = Multi_Head_Attention(heads, d_model, dropout)
        self.msk_attn = Multi_Head_Attention(heads, d_model, dropout)
        self.feedf = FeedForward(d_model).cuda()
        self.dropout_1 = nn.Dropout(dropout).cuda()
        self.dropout_2 = nn.Dropout(dropout).cuda()
        self.dropout_3 = nn.Dropout(dropout).cuda()

    def forward(self, x, e_outputs, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.msk_attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.attn(x2,e_outputs,e_outputs,mask=None))
        x2 = self.norm_3(x)
        x = x +self.dropout_3(self.feedf(x2))
        return x

class Decoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.N = N
        self.embed = Embedder(d_model)
        self.pe = Positional_Encoder(d_model,1)
        self.layers = get_clones(Decoder_Layer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)

    def forward(self, trg, e_outputs, mask = None):
        x = self.embed(trg)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,e_outputs,mask)
        return self.norm(x)

# %% [markdown]
# ## 整体架构定义

# %%
import torch
from torch import nn

class Transformer(nn.Module):
    def __init__(self, trg_vocab, d_model, N, heads, dropout = 0.1):
        super().__init__()
        self.encoder = Encoder(d_model, N , heads, dropout)
        self.decoder = Decoder(d_model, N , heads, dropout)
        self.out = nn.Linear(10*d_model, trg_vocab)

    def forward(self, src, trg_mask=None):
        e_outputs = self.encoder(src, None)
        d_output = self.decoder(src, e_outputs, trg_mask)
        d_intermediate = d_output.view(d_output.size(0), -1)
        output = self.out(d_intermediate)
        output = torch.softmax(output,dim=1)
        return output

# %% [markdown]
# # 数据集与数据处理

# %% [markdown]
# ## NF-CSE-CIC-IDS2018-v2
# 下载数据集:https://rdm.uq.edu.au/files/ce5161d0-ef9c-11ed-827d-e762de186848
#
# 昆士兰大学的sarhan教授团队利用了CSE-CIC-IDS2018数据集的原始pcap文件生成了一个基于NetFlow的数据集，称为NF-CSE-CIC-IDS2018-v2。总的流量数量为18,893,708，其中2,258,141（11.95%）是攻击样本，16,635,567（88.05%）是良性样本。

# %% [markdown]
# ## 数据处理
# 本部分用于对数据进行预处理。由于本数据集的特殊性——正常流量远多于异常攻击流量，因此需要对数据进行下采样与SMOTE处理，前者用于限制数量较多的样本的数量，后者用于对数量较少的样本进行插值处理以增加其数量。

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.neighbors import NearestNeighbors
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import os

label_mapping = {}
directory_path = 'drive/MyDrive/Colab Notebooks/NF-CSE-CIC-IDS2018-v2/data/'


class CICIDSDataset(Dataset):
    def __init__(self, data):
        self.features = data[:, :-3]  # Feature Columns
        self.at_type = data[:, -3]  # Attack Type Column
        self.labels = data[:, -2:]  # 1 Hot Encoded Label

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        feature = torch.from_numpy(self.features[idx]).float()
        label = self.labels[idx]
        at_type = self.at_type[idx]

        return feature, label, at_type


def load_data():
    if os.path.exists(directory_path + "preprocessed/data.csv.gz"):
        print("Loading Preprocessed Data")
        data = pd.read_csv(directory_path + "preprocessed/data.csv.gz", compression='gzip')

    else:
        chunk_size = 100000
        chunks = pd.read_csv(directory_path + 'NF-CSE-CIC-IDS2018-v2.csv', chunksize=chunk_size)
        max_float64 = np.finfo(np.float64).max

        dataframes = []
        features = []
        for chunk in chunks:
            chunk.drop(chunk.columns[[0, 2]], axis=1, inplace=True)
            chunk.columns = chunk.columns.str.strip()
            chunk = chunk.dropna()

            feature_chunk = chunk.drop(columns=['Label', 'Attack_type'])
            numeric_columns = feature_chunk.select_dtypes(include=[np.number]).columns
            feature_chunk[numeric_columns] = np.minimum(feature_chunk[numeric_columns], max_float64)
            labels_chunk = chunk[['Label', 'Attack_type']]
            chunk = pd.concat([feature_chunk, labels_chunk], axis=1)
            dataframes.append(chunk)
        data = pd.concat(dataframes, ignore_index=True)

        # Undersampling & SMOTE

        max_class_size = 100000  # Size of all Classes for Undersampling
        class_counts = data['Attack_type'].value_counts()
        classes_to_undersample = class_counts[class_counts > max_class_size].index

        under_sampler = RandomUnderSampler(sampling_strategy={
            label: 7 * max_class_size if label == "Benign" else max_class_size if label in classes_to_undersample else
            class_counts[label] for label in np.unique(data['Attack_type'])
        }, random_state=42)
        nn_estimator = NearestNeighbors(n_neighbors=5, n_jobs=-1)
        smote = SMOTE(sampling_strategy={
            label: 7 * max_class_size if label == "Benign" else max_class_size for label in np.unique(data['Attack_type'])
        }, k_neighbors=nn_estimator, random_state=42)
        scaler = MinMaxScaler()

        features = data.drop(columns=['Label', 'Attack_type'])
        labels = data['Attack_type']
        # labels['Label'] = labels['Label'].astype(str)
        sampled_features, sampled_labels = under_sampler.fit_resample(features, labels)
        balanced_features, balanced_labels = smote.fit_resample(sampled_features, sampled_labels)
        scaled_data = scaler.fit_transform(balanced_features)

        data = pd.DataFrame(data=scaled_data, columns=features.columns)

        # Encode the actual Attack type for later analysis
        label_encoder = LabelEncoder()
        data['Attack_type'] = label_encoder.fit_transform(balanced_labels)
        label_mapping = dict(enumerate(label_encoder.classes_))

        # 1 Hot Encoding
        data['Attack_Label'] = data['Attack_type'].apply(lambda x: "Attack" if label_mapping[x] != "Benign" else "Benign")
        encoded_labels = pd.get_dummies(data['Attack_Label'], prefix='', prefix_sep='')
        data = pd.concat([data, encoded_labels], axis=1)
        data.drop("Attack_Label", axis=1, inplace=True)

        features = data.drop(columns=['Attack_type', 'Attack', 'Benign'])
        labels = data[['Attack_type', 'Attack', 'Benign']]

        # PCA features extraction
        print('Using PCA...')
        scaler = StandardScaler()
        features = np.nan_to_num(scaler.fit_transform(features))
        pca = PCA(n_components=10, svd_solver='randomized')
        features = pd.DataFrame(pca.fit_transform(features))
        data = pd.concat([features, labels], axis=1)

        label_counts = data['Attack'].value_counts()
        print(label_counts)
        if not os.path.exists(directory_path + 'preprocessed'):
            os.makedirs(directory_path + 'preprocessed')
        data.to_csv(directory_path + 'preprocessed/data.csv.gz', index=False, compression='gzip')
        print("saved")

    train_data, val_data = train_test_split(data, test_size=0.2, random_state=42)
    train_data, val_data = train_data.values, val_data.values

    return train_data, val_data


def get_data_loader(data, batch_size):
    cicids_dataset = CICIDSDataset(data)

    return DataLoader(cicids_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # 模型训练

# %% [markdown]
# 定义训练与评估函数

# %%
import torch
from torch import nn
from torch.nn import functional as F
import numpy as np
import time
import os
import torch
from torch.nn import functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, r2_score, \
    mean_squared_error, log_loss
import matplotlib.pyplot as plt
import seaborn as sns
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import ConfusionMatrixDisplay


def plot_metrics(losses, accs, pres, recs, aucs, f1s):
    epochs = range(1, len(losses) + 1)
    metrics = {'Loss': losses, 'Accuracy': accs, 'Precision': pres, 'Recall': recs, 'F1 Score': f1s}
    categories = list(metrics.keys())
    num_categories = len(categories)
    num_subplots_per_row = 3
    num_rows = (num_categories + num_subplots_per_row - 1) // num_subplots_per_row

    plt.figure(figsize=(16, 4 * num_rows))  # 调整图表大小以适应多子图

    for i, metric_name in enumerate(categories, start=1):
        plt.subplot(num_rows, num_subplots_per_row, i)
        plt.plot(epochs, metrics[metric_name], marker='o')
        plt.title(metric_name)
        plt.xlabel('Epoch')
        plt.ylabel(metric_name.replace(" ", "\n"))  # 分行显示标签，如果标签中有空格的话
        plt.grid(True)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 自动调整子图间距，留出顶部标题空间
    plt.show()


def eval_model(model, loader):
    model.cuda()
    model.eval()
    losses = []
    correct = 0
    predictions = []
    targets = []

    with torch.no_grad():
        for data, target, _ in loader:
            data, target = data.to("cuda"), target.to("cuda")
            output = model(data)
            loss = F.cross_entropy(output, target).item()
            losses.append(loss)
            pred = torch.argmax(output, dim=1)
            correct += torch.eq(torch.argmax(output, dim=1),torch.argmax(target, dim=1)).cpu().sum().item()
            predictions.extend(pred.cpu().numpy())
            targets.extend(target.cpu().numpy())

    eval_loss = np.mean(losses)
    eval_acc = correct / len(loader.dataset)
    targets = torch.tensor(targets)

    # 计算精确率、召回率、F1 分数
    precision = precision_score(torch.argmax(targets, dim=1), predictions, average='macro')
    recall = recall_score(torch.argmax(targets, dim=1), predictions, average='macro')
    f1 = f1_score(torch.argmax(targets, dim=1), predictions, average='macro')

    # 计算 ROC 曲线和 AUC
    try:
        auc = roc_auc_score(torch.argmax(targets, dim=1), predictions, average='weighted')
    except ValueError:
        auc = None

    # 计算混淆矩阵
    conf_matrix = confusion_matrix(torch.argmax(targets, dim=1), predictions)

    # 计算 R-squared
    r_squared = r2_score(torch.argmax(targets, dim=1), predictions)

    # 计算均方误差
    mse = mean_squared_error(torch.argmax(targets, dim=1), predictions)

    # 计算对数损失
    try:
        logloss = log_loss(torch.argmax(targets, dim=1), predictions)
    except ValueError:
        logloss = None

    print("Loss:", eval_loss, "Accuracy:", eval_acc)
    print("Precision:", precision, "Recall:", recall, "F1 Score:", f1)
    print("AUC:", auc)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("R-squared:", r_squared)
    print("Mean Squared Error:", mse)
    print("Log Loss:", logloss)

    return eval_loss, eval_acc, precision, recall, f1, auc, r_squared, mse, logloss, conf_matrix


def train_model(model, opt, epochs, data, eval_data, path, print_every=100):
    model.cuda()

    pretrained_path = "drive/MyDrive/Colab Notebooks/NF-UNSW-NB15-v2/pretrained"
    top_acc = 0.
    scheduler = StepLR(opt, step_size=1, gamma=0.9)

    if os.path.exists(pretrained_path + "/" + path):
        print("Loading Pretrained Model")
        state = torch.load(pretrained_path + "/" + path)
        model.load_state_dict(state["model_state_dict"])
        start_epoch = state["epoch"] + 1
        losses = state["ep_loss"]
        accs = state["ep_acc"]
        top_acc = max(accs)
        aucs = state["aucs"]
        f1s = state['f1s']
        recs = state['recs']
        pres = state['pres']
        conf_matrix = state['conf_matrix']
    else:
        start_epoch = 0
        losses, accs = [], []
        aucs = []
        f1s = []
        recs = []
        pres = []
        try:
            os.mkdir(pretrained_path)
        except OSError as error:
            pass

    start = time.time()
    temp = start

    for epoch in range(start_epoch, epochs):
        model.train()
        total_loss = 0
        for i, batch in enumerate(data):
            src, trg, _ = batch
            src, trg = src.cuda(), trg.cuda()

            if isinstance(model, Transformer):
                trg_mask = get_mask(128, 8, 10)
            else:
                trg_mask = None

            preds = model(src, trg_mask)
            opt.zero_grad()
            loss = F.cross_entropy(preds, trg)
            loss.backward()
            opt.step()
            scheduler.step()

            total_loss += loss.data
            if (i + 1) % print_every == 0:
                loss_avg = total_loss / print_every
                print("time = %dm, epoch %d, iter = %d, loss = %.3f, \
                # %ds per %d iters" % ((time.time() - start) // 60,
                                     epoch + 1, i + 1, loss_avg, time.time() - temp,
                                     print_every))
                total_loss = 0
                temp = time.time()
        eval_loss, eval_acc, precision, recall, f1, auc, r_squared, mse, logloss, conf_matrix = eval_model(model, eval_data)
        losses.append(eval_loss)
        accs.append(eval_acc)
        pres.append(precision)
        recs.append(recall)
        aucs.append(auc)
        f1s.append(f1)

        plot_metrics(losses, accs, pres, recs, aucs, f1s)

        if eval_acc > top_acc:
            top_state = {
              'model_state_dict': model.state_dict(),
              'epoch': epoch,
              'ep_loss': losses,
              'ep_acc': accs,
              'pres': pres,
              'recs': recs,
              'f1s': f1s,
              'aucs': aucs,
              'conf_matrix': conf_matrix
            }
            torch.save(top_state, pretrained_path + "/max_" + path)
        state = {
            'model_state_dict': model.state_dict(),
            'epoch': epoch,
            'ep_loss': losses,
            'ep_acc': accs,
            'pres': pres,
            'recs': recs,
            'f1s': f1s,
            'aucs': aucs,
            'conf_matrix': conf_matrix
        }
        torch.save(state, pretrained_path + "/" + path)

# %% [markdown]
# 设置参数并训练模型

# %%
import torch
from torch import nn
from torchsummary import summary


learning_rate = 1e-4
batch_size = 128
epochs = 10
dropout_rate = 0.5
d_model = 32
heads = 8
N = 6
trg_vocab = 2

train_data, val_data = load_data()

train_loader = get_data_loader(train_data, batch_size)
val_loader = get_data_loader(val_data, batch_size)

model = Transformer(trg_vocab, d_model, N, heads, dropout_rate)
save_path = "pretrained.pt"

for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)
model = model.to("cuda:0")
summary(model, (10, ))

optim = torch.optim.RAdam(model.parameters(), lr=learning_rate)

train_model(model, optim, epochs, train_loader, val_loader, save_path)
# Out:
# Loading Preprocessed Data
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#           Embedder-1               [-1, 10, 32]               0
# Positional_Encoder-2               [-1, 10, 32]               0
#               Norm-3               [-1, 10, 32]              32
#             Linear-4               [-1, 10, 32]           1,056
#             Linear-5               [-1, 10, 32]           1,056
#             Linear-6               [-1, 10, 32]           1,056
#            Dropout-7            [-1, 8, 10, 10]               0
#             Linear-8               [-1, 10, 32]           1,056
# Multi_Head_Attention-9               [-1, 10, 32]               0
#           Dropout-10               [-1, 10, 32]               0
#              Norm-11               [-1, 10, 32]              32
#            Linear-12             [-1, 10, 1024]          33,792
#           Dropout-13             [-1, 10, 1024]               0
#            Linear-14               [-1, 10, 32]          32,800
#       FeedForward-15               [-1, 10, 32]               0
#           Dropout-16               [-1, 10, 32]               0
#     Encoder_Layer-17               [-1, 10, 32]               0
#              Norm-18               [-1, 10, 32]              32
#            Linear-19               [-1, 10, 32]           1,056
#            Linear-20               [-1, 10, 32]           1,056
#            Linear-21               [-1, 10, 32]           1,056
#           Dropout-22            [-1, 8, 10, 10]               0
#            Linear-23               [-1, 10, 32]           1,056
# Multi_Head_Attention-24               [-1, 10, 32]               0
#           Dropout-25               [-1, 10, 32]               0
#              Norm-26               [-1, 10, 32]              32
#            Linear-27             [-1, 10, 1024]          33,792
#           Dropout-28             [-1, 10, 1024]               0
#            Linear-29               [-1, 10, 32]          32,800
#       FeedForward-30               [-1, 10, 32]               0
#           Dropout-31               [-1, 10, 32]               0
#     Encoder_Layer-32               [-1, 10, 32]               0
#              Norm-33               [-1, 10, 32]              32
#            Linear-34               [-1, 10, 32]           1,056
#            Linear-35               [-1, 10, 32]           1,056
#            Linear-36               [-1, 10, 32]           1,056
#           Dropout-37            [-1, 8, 10, 10]               0
#            Linear-38               [-1, 10, 32]           1,056
# Multi_Head_Attention-39               [-1, 10, 32]               0
#           Dropout-40               [-1, 10, 32]               0
#              Norm-41               [-1, 10, 32]              32
#            Linear-42             [-1, 10, 1024]          33,792
#           Dropout-43             [-1, 10, 1024]               0
#            Linear-44               [-1, 10, 32]          32,800
#       FeedForward-45               [-1, 10, 32]               0
#           Dropout-46               [-1, 10, 32]               0
#     Encoder_Layer-47               [-1, 10, 32]               0
#              Norm-48               [-1, 10, 32]              32
#            Linear-49               [-1, 10, 32]           1,056
#            Linear-50               [-1, 10, 32]           1,056
#            Linear-51               [-1, 10, 32]           1,056
#           Dropout-52            [-1, 8, 10, 10]               0
#            Linear-53               [-1, 10, 32]           1,056
# Multi_Head_Attention-54               [-1, 10, 32]               0
#           Dropout-55               [-1, 10, 32]               0
#              Norm-56               [-1, 10, 32]              32
#            Linear-57             [-1, 10, 1024]          33,792
#           Dropout-58             [-1, 10, 1024]               0
#            Linear-59               [-1, 10, 32]          32,800
#       FeedForward-60               [-1, 10, 32]               0
#           Dropout-61               [-1, 10, 32]               0
#     Encoder_Layer-62               [-1, 10, 32]               0
#              Norm-63               [-1, 10, 32]              32
#            Linear-64               [-1, 10, 32]           1,056
#            Linear-65               [-1, 10, 32]           1,056
#            Linear-66               [-1, 10, 32]           1,056
#           Dropout-67            [-1, 8, 10, 10]               0
#            Linear-68               [-1, 10, 32]           1,056
# Multi_Head_Attention-69               [-1, 10, 32]               0
#           Dropout-70               [-1, 10, 32]               0
#              Norm-71               [-1, 10, 32]              32
#            Linear-72             [-1, 10, 1024]          33,792
#           Dropout-73             [-1, 10, 1024]               0
#            Linear-74               [-1, 10, 32]          32,800
#       FeedForward-75               [-1, 10, 32]               0
#           Dropout-76               [-1, 10, 32]               0
#     Encoder_Layer-77               [-1, 10, 32]               0
#              Norm-78               [-1, 10, 32]              32
#            Linear-79               [-1, 10, 32]           1,056
#            Linear-80               [-1, 10, 32]           1,056
#            Linear-81               [-1, 10, 32]           1,056
#           Dropout-82            [-1, 8, 10, 10]               0
#            Linear-83               [-1, 10, 32]           1,056
# Multi_Head_Attention-84               [-1, 10, 32]               0
#           Dropout-85               [-1, 10, 32]               0
#              Norm-86               [-1, 10, 32]              32
#            Linear-87             [-1, 10, 1024]          33,792
#           Dropout-88             [-1, 10, 1024]               0
#            Linear-89               [-1, 10, 32]          32,800
#       FeedForward-90               [-1, 10, 32]               0
#           Dropout-91               [-1, 10, 32]               0
#     Encoder_Layer-92               [-1, 10, 32]               0
#              Norm-93               [-1, 10, 32]              32
#           Encoder-94               [-1, 10, 32]               0
#          Embedder-95               [-1, 10, 32]               0
# Positional_Encoder-96               [-1, 10, 32]               0
#              Norm-97               [-1, 10, 32]              32
#            Linear-98               [-1, 10, 32]           1,056
#            Linear-99               [-1, 10, 32]           1,056
#           Linear-100               [-1, 10, 32]           1,056
#          Dropout-101            [-1, 8, 10, 10]               0
#           Linear-102               [-1, 10, 32]           1,056
# Multi_Head_Attention-103               [-1, 10, 32]               0
#          Dropout-104               [-1, 10, 32]               0
#             Norm-105               [-1, 10, 32]              32
#           Linear-106               [-1, 10, 32]           1,056
#           Linear-107               [-1, 10, 32]           1,056
#           Linear-108               [-1, 10, 32]           1,056
#          Dropout-109            [-1, 8, 10, 10]               0
#           Linear-110               [-1, 10, 32]           1,056
# Multi_Head_Attention-111               [-1, 10, 32]               0
#          Dropout-112               [-1, 10, 32]               0
#             Norm-113               [-1, 10, 32]              32
#           Linear-114             [-1, 10, 1024]          33,792
#          Dropout-115             [-1, 10, 1024]               0
#           Linear-116               [-1, 10, 32]          32,800
#      FeedForward-117               [-1, 10, 32]               0
#          Dropout-118               [-1, 10, 32]               0
#    Decoder_Layer-119               [-1, 10, 32]               0
#             Norm-120               [-1, 10, 32]              32
#           Linear-121               [-1, 10, 32]           1,056
#           Linear-122               [-1, 10, 32]           1,056
#           Linear-123               [-1, 10, 32]           1,056
#          Dropout-124            [-1, 8, 10, 10]               0
#           Linear-125               [-1, 10, 32]           1,056
# Multi_Head_Attention-126               [-1, 10, 32]               0
#          Dropout-127               [-1, 10, 32]               0
#             Norm-128               [-1, 10, 32]              32
#           Linear-129               [-1, 10, 32]           1,056
#           Linear-130               [-1, 10, 32]           1,056
#           Linear-131               [-1, 10, 32]           1,056
#          Dropout-132            [-1, 8, 10, 10]               0
#           Linear-133               [-1, 10, 32]           1,056
# Multi_Head_Attention-134               [-1, 10, 32]               0
#          Dropout-135               [-1, 10, 32]               0
#             Norm-136               [-1, 10, 32]              32
#           Linear-137             [-1, 10, 1024]          33,792
#          Dropout-138             [-1, 10, 1024]               0
#           Linear-139               [-1, 10, 32]          32,800
#      FeedForward-140               [-1, 10, 32]               0
#          Dropout-141               [-1, 10, 32]               0
#    Decoder_Layer-142               [-1, 10, 32]               0
#             Norm-143               [-1, 10, 32]              32
#           Linear-144               [-1, 10, 32]           1,056
#           Linear-145               [-1, 10, 32]           1,056
#           Linear-146               [-1, 10, 32]           1,056
#          Dropout-147            [-1, 8, 10, 10]               0
#           Linear-148               [-1, 10, 32]           1,056
# Multi_Head_Attention-149               [-1, 10, 32]               0
#          Dropout-150               [-1, 10, 32]               0
#             Norm-151               [-1, 10, 32]              32
#           Linear-152               [-1, 10, 32]           1,056
#           Linear-153               [-1, 10, 32]           1,056
#           Linear-154               [-1, 10, 32]           1,056
#          Dropout-155            [-1, 8, 10, 10]               0
#           Linear-156               [-1, 10, 32]           1,056
# Multi_Head_Attention-157               [-1, 10, 32]               0
#          Dropout-158               [-1, 10, 32]               0
#             Norm-159               [-1, 10, 32]              32
#           Linear-160             [-1, 10, 1024]          33,792
#          Dropout-161             [-1, 10, 1024]               0
#           Linear-162               [-1, 10, 32]          32,800
#      FeedForward-163               [-1, 10, 32]               0
#          Dropout-164               [-1, 10, 32]               0
#    Decoder_Layer-165               [-1, 10, 32]               0
#             Norm-166               [-1, 10, 32]              32
#           Linear-167               [-1, 10, 32]           1,056
#           Linear-168               [-1, 10, 32]           1,056
#           Linear-169               [-1, 10, 32]           1,056
#          Dropout-170            [-1, 8, 10, 10]               0
#           Linear-171               [-1, 10, 32]           1,056
# Multi_Head_Attention-172               [-1, 10, 32]               0
#          Dropout-173               [-1, 10, 32]               0
#             Norm-174               [-1, 10, 32]              32
#           Linear-175               [-1, 10, 32]           1,056
#           Linear-176               [-1, 10, 32]           1,056
#           Linear-177               [-1, 10, 32]           1,056
#          Dropout-178            [-1, 8, 10, 10]               0
#           Linear-179               [-1, 10, 32]           1,056
# Multi_Head_Attention-180               [-1, 10, 32]               0
#          Dropout-181               [-1, 10, 32]               0
#             Norm-182               [-1, 10, 32]              32
#           Linear-183             [-1, 10, 1024]          33,792
#          Dropout-184             [-1, 10, 1024]               0
#           Linear-185               [-1, 10, 32]          32,800
#      FeedForward-186               [-1, 10, 32]               0
#          Dropout-187               [-1, 10, 32]               0
#    Decoder_Layer-188               [-1, 10, 32]               0
#             Norm-189               [-1, 10, 32]              32
#           Linear-190               [-1, 10, 32]           1,056
#           Linear-191               [-1, 10, 32]           1,056
#           Linear-192               [-1, 10, 32]           1,056
#          Dropout-193            [-1, 8, 10, 10]               0
#           Linear-194               [-1, 10, 32]           1,056
# Multi_Head_Attention-195               [-1, 10, 32]               0
#          Dropout-196               [-1, 10, 32]               0
#             Norm-197               [-1, 10, 32]              32
#           Linear-198               [-1, 10, 32]           1,056
#           Linear-199               [-1, 10, 32]           1,056
#           Linear-200               [-1, 10, 32]           1,056
#          Dropout-201            [-1, 8, 10, 10]               0
#           Linear-202               [-1, 10, 32]           1,056
# Multi_Head_Attention-203               [-1, 10, 32]               0
#          Dropout-204               [-1, 10, 32]               0
#             Norm-205               [-1, 10, 32]              32
#           Linear-206             [-1, 10, 1024]          33,792
#          Dropout-207             [-1, 10, 1024]               0
#           Linear-208               [-1, 10, 32]          32,800
#      FeedForward-209               [-1, 10, 32]               0
#          Dropout-210               [-1, 10, 32]               0
#    Decoder_Layer-211               [-1, 10, 32]               0
#             Norm-212               [-1, 10, 32]              32
#           Linear-213               [-1, 10, 32]           1,056
#           Linear-214               [-1, 10, 32]           1,056
#           Linear-215               [-1, 10, 32]           1,056
#          Dropout-216            [-1, 8, 10, 10]               0
#           Linear-217               [-1, 10, 32]           1,056
# Multi_Head_Attention-218               [-1, 10, 32]               0
#          Dropout-219               [-1, 10, 32]               0
#             Norm-220               [-1, 10, 32]              32
#           Linear-221               [-1, 10, 32]           1,056
#           Linear-222               [-1, 10, 32]           1,056
#           Linear-223               [-1, 10, 32]           1,056
#          Dropout-224            [-1, 8, 10, 10]               0
#           Linear-225               [-1, 10, 32]           1,056
# Multi_Head_Attention-226               [-1, 10, 32]               0
#          Dropout-227               [-1, 10, 32]               0
#             Norm-228               [-1, 10, 32]              32
#           Linear-229             [-1, 10, 1024]          33,792
#          Dropout-230             [-1, 10, 1024]               0
#           Linear-231               [-1, 10, 32]          32,800
#      FeedForward-232               [-1, 10, 32]               0
#          Dropout-233               [-1, 10, 32]               0
#    Decoder_Layer-234               [-1, 10, 32]               0
#             Norm-235               [-1, 10, 32]              32
#          Decoder-236               [-1, 10, 32]               0
#           Linear-237                    [-1, 2]             642
# ================================================================
# Total params: 876,802
# Trainable params: 875,778
# Non-trainable params: 1,024
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.46
# Params size (MB): 3.34
# Estimated Total Size (MB): 5.80
# ----------------------------------------------------------------
# time = 0m, epoch 1, iter = 100, loss = 0.641,                 6s per 100 iters
# time = 0m, epoch 1, iter = 200, loss = 0.572,                 5s per 100 iters
# time = 0m, epoch 1, iter = 300, loss = 0.520,                 6s per 100 iters
# time = 0m, epoch 1, iter = 400, loss = 0.493,                 5s per 100 iters
# time = 0m, epoch 1, iter = 500, loss = 0.472,                 6s per 100 iters
# time = 0m, epoch 1, iter = 600, loss = 0.464,                 5s per 100 iters
# time = 0m, epoch 1, iter = 700, loss = 0.444,                 6s per 100 iters
# time = 0m, epoch 1, iter = 800, loss = 0.433,                 5s per 100 iters
# time = 0m, epoch 1, iter = 900, loss = 0.427,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1000, loss = 0.419,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1100, loss = 0.417,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1200, loss = 0.412,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1300, loss = 0.412,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1400, loss = 0.405,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1500, loss = 0.400,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1600, loss = 0.397,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1700, loss = 0.401,                 5s per 100 iters
# time = 1m, epoch 1, iter = 1800, loss = 0.398,                 6s per 100 iters
# time = 1m, epoch 1, iter = 1900, loss = 0.399,                 5s per 100 iters
# time = 1m, epoch 1, iter = 2000, loss = 0.396,                 5s per 100 iters
# time = 2m, epoch 1, iter = 2100, loss = 0.395,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2200, loss = 0.394,                 5s per 100 iters
# time = 2m, epoch 1, iter = 2300, loss = 0.397,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2400, loss = 0.391,                 5s per 100 iters
# time = 2m, epoch 1, iter = 2500, loss = 0.390,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2600, loss = 0.392,                 5s per 100 iters
# time = 2m, epoch 1, iter = 2700, loss = 0.387,                 6s per 100 iters
# time = 2m, epoch 1, iter = 2800, loss = 0.389,                 9s per 100 iters
# time = 2m, epoch 1, iter = 2900, loss = 0.392,                 8s per 100 iters
# time = 3m, epoch 1, iter = 3000, loss = 0.391,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3100, loss = 0.390,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3200, loss = 0.386,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3300, loss = 0.391,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3400, loss = 0.385,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3500, loss = 0.384,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3600, loss = 0.385,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3700, loss = 0.385,                 6s per 100 iters
# time = 3m, epoch 1, iter = 3800, loss = 0.387,                 5s per 100 iters
# time = 3m, epoch 1, iter = 3900, loss = 0.380,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4000, loss = 0.386,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4100, loss = 0.384,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4200, loss = 0.382,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4300, loss = 0.384,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4400, loss = 0.384,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4500, loss = 0.383,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4600, loss = 0.384,                 7s per 100 iters
# time = 4m, epoch 1, iter = 4700, loss = 0.381,                 5s per 100 iters
# time = 4m, epoch 1, iter = 4800, loss = 0.380,                 6s per 100 iters
# time = 4m, epoch 1, iter = 4900, loss = 0.383,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5000, loss = 0.381,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5100, loss = 0.385,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5200, loss = 0.382,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5300, loss = 0.379,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5400, loss = 0.381,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5500, loss = 0.382,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5600, loss = 0.383,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5700, loss = 0.382,                 6s per 100 iters
# time = 5m, epoch 1, iter = 5800, loss = 0.380,                 5s per 100 iters
# time = 5m, epoch 1, iter = 5900, loss = 0.381,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6000, loss = 0.384,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6100, loss = 0.378,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6200, loss = 0.381,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6300, loss = 0.375,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6400, loss = 0.382,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6500, loss = 0.377,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6600, loss = 0.381,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6700, loss = 0.383,                 5s per 100 iters
# time = 6m, epoch 1, iter = 6800, loss = 0.376,                 6s per 100 iters
# time = 6m, epoch 1, iter = 6900, loss = 0.379,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7000, loss = 0.377,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7100, loss = 0.379,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7200, loss = 0.379,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7300, loss = 0.381,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7400, loss = 0.380,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7500, loss = 0.380,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7600, loss = 0.380,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7700, loss = 0.379,                 6s per 100 iters
# time = 7m, epoch 1, iter = 7800, loss = 0.378,                 5s per 100 iters
# time = 7m, epoch 1, iter = 7900, loss = 0.378,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8000, loss = 0.375,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8100, loss = 0.379,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8200, loss = 0.377,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8300, loss = 0.380,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8400, loss = 0.386,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8500, loss = 0.378,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8600, loss = 0.377,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8700, loss = 0.379,                 5s per 100 iters
# time = 8m, epoch 1, iter = 8800, loss = 0.377,                 6s per 100 iters
# time = 8m, epoch 1, iter = 8900, loss = 0.376,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9000, loss = 0.378,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9100, loss = 0.376,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9200, loss = 0.380,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9300, loss = 0.378,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9400, loss = 0.383,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9500, loss = 0.377,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9600, loss = 0.380,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9700, loss = 0.377,                 6s per 100 iters
# time = 9m, epoch 1, iter = 9800, loss = 0.380,                 5s per 100 iters
# time = 9m, epoch 1, iter = 9900, loss = 0.375,                 6s per 100 iters
# time = 10m, epoch 1, iter = 10000, loss = 0.378,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10100, loss = 0.374,                 6s per 100 iters
# time = 10m, epoch 1, iter = 10200, loss = 0.380,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10300, loss = 0.377,                 6s per 100 iters
# time = 10m, epoch 1, iter = 10400, loss = 0.379,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10500, loss = 0.375,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10600, loss = 0.377,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10700, loss = 0.373,                 5s per 100 iters
# time = 10m, epoch 1, iter = 10800, loss = 0.379,                 6s per 100 iters
# time = 10m, epoch 1, iter = 10900, loss = 0.378,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11000, loss = 0.376,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11100, loss = 0.375,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11200, loss = 0.375,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11300, loss = 0.375,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11400, loss = 0.379,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11500, loss = 0.375,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11600, loss = 0.375,                 6s per 100 iters
# time = 11m, epoch 1, iter = 11700, loss = 0.380,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11800, loss = 0.381,                 5s per 100 iters
# time = 11m, epoch 1, iter = 11900, loss = 0.379,                 6s per 100 iters
# time = 11m, epoch 1, iter = 12000, loss = 0.378,                 5s per 100 iters
# time = 12m, epoch 1, iter = 12100, loss = 0.373,                 6s per 100 iters
# time = 12m, epoch 1, iter = 12200, loss = 0.376,                 5s per 100 iters
# time = 12m, epoch 1, iter = 12300, loss = 0.373,                 6s per 100 iters
# time = 12m, epoch 1, iter = 12400, loss = 0.378,                 5s per 100 iters
# time = 12m, epoch 1, iter = 12500, loss = 0.379,                 6s per 100 iters
# time = 12m, epoch 1, iter = 12600, loss = 0.379,                 5s per 100 iters
# time = 12m, epoch 1, iter = 12700, loss = 0.378,                 6s per 100 iters
# time = 12m, epoch 1, iter = 12800, loss = 0.377,                 5s per 100 iters
# time = 12m, epoch 1, iter = 12900, loss = 0.375,                 5s per 100 iters
# time = 12m, epoch 1, iter = 13000, loss = 0.380,                 6s per 100 iters
# time = 13m, epoch 1, iter = 13100, loss = 0.375,                 5s per 100 iters
# <ipython-input-29-7a851d4027a5>:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:275.)
#   targets = torch.tensor(targets)
# Loss: 0.3748153505832244 Accuracy: 0.9382833333333334
# Precision: 0.9226247865719572 Recall: 0.9473778546114328 F1 Score: 0.9326030509309149
# AUC: 0.9473778546114326
# Confusion Matrix:
# [[258005  22363]
#  [  3558 136074]]
# R-squared: 0.7219085476560816
# Mean Squared Error: 0.06171666666666667
# Log Loss: 2.2244941416650135
# time = 14m, epoch 2, iter = 100, loss = 0.375,                 63s per 100 iters
# time = 14m, epoch 2, iter = 200, loss = 0.374,                 6s per 100 iters
# time = 14m, epoch 2, iter = 300, loss = 0.372,                 5s per 100 iters
# time = 14m, epoch 2, iter = 400, loss = 0.373,                 6s per 100 iters
# time = 14m, epoch 2, iter = 500, loss = 0.375,                 5s per 100 iters
# time = 14m, epoch 2, iter = 600, loss = 0.373,                 5s per 100 iters
# time = 14m, epoch 2, iter = 700, loss = 0.378,                 5s per 100 iters
# time = 14m, epoch 2, iter = 800, loss = 0.374,                 5s per 100 iters
# time = 14m, epoch 2, iter = 900, loss = 0.379,                 6s per 100 iters
# time = 15m, epoch 2, iter = 1000, loss = 0.375,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1100, loss = 0.372,                 6s per 100 iters
# time = 15m, epoch 2, iter = 1200, loss = 0.376,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1300, loss = 0.377,                 6s per 100 iters
# time = 15m, epoch 2, iter = 1400, loss = 0.377,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1500, loss = 0.374,                 6s per 100 iters
# time = 15m, epoch 2, iter = 1600, loss = 0.377,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1700, loss = 0.378,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1800, loss = 0.378,                 5s per 100 iters
# time = 15m, epoch 2, iter = 1900, loss = 0.374,                 5s per 100 iters
# time = 16m, epoch 2, iter = 2000, loss = 0.375,                 6s per 100 iters
# time = 16m, epoch 2, iter = 2100, loss = 0.373,                 5s per 100 iters
# time = 16m, epoch 2, iter = 2200, loss = 0.380,                 6s per 100 iters
# time = 16m, epoch 2, iter = 2300, loss = 0.376,                 5s per 100 iters
# time = 16m, epoch 2, iter = 2400, loss = 0.374,                 6s per 100 iters
# time = 16m, epoch 2, iter = 2500, loss = 0.376,                 5s per 100 iters
# time = 16m, epoch 2, iter = 2600, loss = 0.377,                 6s per 100 iters
# time = 16m, epoch 2, iter = 2700, loss = 0.376,                 5s per 100 iters
# time = 16m, epoch 2, iter = 2800, loss = 0.377,                 6s per 100 iters
# time = 16m, epoch 2, iter = 2900, loss = 0.377,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3000, loss = 0.378,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3100, loss = 0.379,                 6s per 100 iters
# time = 17m, epoch 2, iter = 3200, loss = 0.380,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3300, loss = 0.377,                 6s per 100 iters
# time = 17m, epoch 2, iter = 3400, loss = 0.379,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3500, loss = 0.375,                 6s per 100 iters
# time = 17m, epoch 2, iter = 3600, loss = 0.372,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3700, loss = 0.372,                 6s per 100 iters
# time = 17m, epoch 2, iter = 3800, loss = 0.377,                 5s per 100 iters
# time = 17m, epoch 2, iter = 3900, loss = 0.377,                 6s per 100 iters
# time = 18m, epoch 2, iter = 4000, loss = 0.379,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4100, loss = 0.373,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4200, loss = 0.373,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4300, loss = 0.378,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4400, loss = 0.376,                 6s per 100 iters
# time = 18m, epoch 2, iter = 4500, loss = 0.375,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4600, loss = 0.373,                 6s per 100 iters
# time = 18m, epoch 2, iter = 4700, loss = 0.370,                 5s per 100 iters
# time = 18m, epoch 2, iter = 4800, loss = 0.375,                 6s per 100 iters
# time = 18m, epoch 2, iter = 4900, loss = 0.376,                 5s per 100 iters
# time = 18m, epoch 2, iter = 5000, loss = 0.376,                 6s per 100 iters
# time = 19m, epoch 2, iter = 5100, loss = 0.376,                 5s per 100 iters
# time = 19m, epoch 2, iter = 5200, loss = 0.376,                 5s per 100 iters
# time = 19m, epoch 2, iter = 5300, loss = 0.376,                 6s per 100 iters
# time = 19m, epoch 2, iter = 5400, loss = 0.375,                 5s per 100 iters
# time = 19m, epoch 2, iter = 5500, loss = 0.376,                 6s per 100 iters
# time = 19m, epoch 2, iter = 5600, loss = 0.373,                 5s per 100 iters
# time = 19m, epoch 2, iter = 5700, loss = 0.377,                 6s per 100 iters
# time = 19m, epoch 2, iter = 5800, loss = 0.375,                 5s per 100 iters
# time = 19m, epoch 2, iter = 5900, loss = 0.379,                 6s per 100 iters
# time = 19m, epoch 2, iter = 6000, loss = 0.378,                 5s per 100 iters
# time = 20m, epoch 2, iter = 6100, loss = 0.378,                 6s per 100 iters
# time = 20m, epoch 2, iter = 6200, loss = 0.377,                 5s per 100 iters
# time = 20m, epoch 2, iter = 6300, loss = 0.375,                 6s per 100 iters
# time = 20m, epoch 2, iter = 6400, loss = 0.375,                 5s per 100 iters
# time = 20m, epoch 2, iter = 6500, loss = 0.376,                 5s per 100 iters
# time = 20m, epoch 2, iter = 6600, loss = 0.376,                 6s per 100 iters
# time = 20m, epoch 2, iter = 6700, loss = 0.374,                 5s per 100 iters
# time = 20m, epoch 2, iter = 6800, loss = 0.376,                 6s per 100 iters
# time = 20m, epoch 2, iter = 6900, loss = 0.379,                 5s per 100 iters
# time = 20m, epoch 2, iter = 7000, loss = 0.376,                 6s per 100 iters
# time = 21m, epoch 2, iter = 7100, loss = 0.375,                 5s per 100 iters
# time = 21m, epoch 2, iter = 7200, loss = 0.375,                 6s per 100 iters
# time = 21m, epoch 2, iter = 7300, loss = 0.379,                 5s per 100 iters
# time = 21m, epoch 2, iter = 7400, loss = 0.374,                 6s per 100 iters
# time = 21m, epoch 2, iter = 7500, loss = 0.378,                 5s per 100 iters
# time = 21m, epoch 2, iter = 7600, loss = 0.372,                 6s per 100 iters
# time = 21m, epoch 2, iter = 7700, loss = 0.375,                 5s per 100 iters
# time = 21m, epoch 2, iter = 7800, loss = 0.370,                 5s per 100 iters
# time = 21m, epoch 2, iter = 7900, loss = 0.374,                 6s per 100 iters
# time = 21m, epoch 2, iter = 8000, loss = 0.378,                 5s per 100 iters
# time = 22m, epoch 2, iter = 8100, loss = 0.379,                 6s per 100 iters
# time = 22m, epoch 2, iter = 8200, loss = 0.375,                 5s per 100 iters
# time = 22m, epoch 2, iter = 8300, loss = 0.374,                 6s per 100 iters
# time = 22m, epoch 2, iter = 8400, loss = 0.375,                 5s per 100 iters
# time = 22m, epoch 2, iter = 8500, loss = 0.376,                 6s per 100 iters
# time = 22m, epoch 2, iter = 8600, loss = 0.376,                 5s per 100 iters
# time = 22m, epoch 2, iter = 8700, loss = 0.376,                 6s per 100 iters
# time = 22m, epoch 2, iter = 8800, loss = 0.375,                 5s per 100 iters
# time = 22m, epoch 2, iter = 8900, loss = 0.378,                 6s per 100 iters
# time = 23m, epoch 2, iter = 9000, loss = 0.376,                 5s per 100 iters
# time = 23m, epoch 2, iter = 9100, loss = 0.371,                 5s per 100 iters
# time = 23m, epoch 2, iter = 9200, loss = 0.376,                 6s per 100 iters
# time = 23m, epoch 2, iter = 9300, loss = 0.374,                 5s per 100 iters
# time = 23m, epoch 2, iter = 9400, loss = 0.377,                 6s per 100 iters
# time = 23m, epoch 2, iter = 9500, loss = 0.376,                 5s per 100 iters
# time = 23m, epoch 2, iter = 9600, loss = 0.377,                 6s per 100 iters
# time = 23m, epoch 2, iter = 9700, loss = 0.374,                 5s per 100 iters
# time = 23m, epoch 2, iter = 9800, loss = 0.376,                 6s per 100 iters
# time = 23m, epoch 2, iter = 9900, loss = 0.370,                 5s per 100 iters
# time = 23m, epoch 2, iter = 10000, loss = 0.374,                 6s per 100 iters
# time = 24m, epoch 2, iter = 10100, loss = 0.376,                 5s per 100 iters
# time = 24m, epoch 2, iter = 10200, loss = 0.373,                 6s per 100 iters
# time = 24m, epoch 2, iter = 10300, loss = 0.375,                 6s per 100 iters
# time = 24m, epoch 2, iter = 10400, loss = 0.378,                 5s per 100 iters
# time = 24m, epoch 2, iter = 10500, loss = 0.376,                 6s per 100 iters
# time = 24m, epoch 2, iter = 10600, loss = 0.374,                 5s per 100 iters
# time = 24m, epoch 2, iter = 10700, loss = 0.376,                 6s per 100 iters
# time = 24m, epoch 2, iter = 10800, loss = 0.372,                 5s per 100 iters
# time = 24m, epoch 2, iter = 10900, loss = 0.373,                 6s per 100 iters
# time = 24m, epoch 2, iter = 11000, loss = 0.373,                 5s per 100 iters
# time = 25m, epoch 2, iter = 11100, loss = 0.376,                 6s per 100 iters
# time = 25m, epoch 2, iter = 11200, loss = 0.379,                 5s per 100 iters
# time = 25m, epoch 2, iter = 11300, loss = 0.378,                 6s per 100 iters
# time = 25m, epoch 2, iter = 11400, loss = 0.374,                 5s per 100 iters
# time = 25m, epoch 2, iter = 11500, loss = 0.377,                 5s per 100 iters
# time = 25m, epoch 2, iter = 11600, loss = 0.374,                 6s per 100 iters
# time = 25m, epoch 2, iter = 11700, loss = 0.373,                 5s per 100 iters
# time = 25m, epoch 2, iter = 11800, loss = 0.374,                 6s per 100 iters
# time = 25m, epoch 2, iter = 11900, loss = 0.370,                 5s per 100 iters
# time = 25m, epoch 2, iter = 12000, loss = 0.375,                 6s per 100 iters
# time = 26m, epoch 2, iter = 12100, loss = 0.374,                 5s per 100 iters
# time = 26m, epoch 2, iter = 12200, loss = 0.373,                 6s per 100 iters
# time = 26m, epoch 2, iter = 12300, loss = 0.374,                 5s per 100 iters
# time = 26m, epoch 2, iter = 12400, loss = 0.375,                 6s per 100 iters
# time = 26m, epoch 2, iter = 12500, loss = 0.377,                 5s per 100 iters
# time = 26m, epoch 2, iter = 12600, loss = 0.379,                 6s per 100 iters
# time = 26m, epoch 2, iter = 12700, loss = 0.374,                 6s per 100 iters
# time = 26m, epoch 2, iter = 12800, loss = 0.370,                 5s per 100 iters
# time = 26m, epoch 2, iter = 12900, loss = 0.372,                 6s per 100 iters
# time = 26m, epoch 2, iter = 13000, loss = 0.377,                 5s per 100 iters
# time = 27m, epoch 2, iter = 13100, loss = 0.373,                 6s per 100 iters
# Loss: 0.3722872742254368 Accuracy: 0.9408
# Precision: 0.9254162426781098 Recall: 0.9497392068729706 F1 Score: 0.9352997600671504
# AUC: 0.9497392068729705
# Confusion Matrix:
# [[258797  21571]
#  [  3293 136339]]
# R-squared: 0.7332484907573323
# Mean Squared Error: 0.0592
# Log Loss: 2.133784280635736
# time = 28m, epoch 3, iter = 100, loss = 0.375,                 63s per 100 iters
# time = 28m, epoch 3, iter = 200, loss = 0.375,                 5s per 100 iters
# time = 28m, epoch 3, iter = 300, loss = 0.375,                 6s per 100 iters
# time = 28m, epoch 3, iter = 400, loss = 0.376,                 5s per 100 iters
# time = 28m, epoch 3, iter = 500, loss = 0.373,                 6s per 100 iters
# time = 28m, epoch 3, iter = 600, loss = 0.375,                 5s per 100 iters
# time = 28m, epoch 3, iter = 700, loss = 0.375,                 5s per 100 iters
# time = 28m, epoch 3, iter = 800, loss = 0.373,                 6s per 100 iters
# time = 28m, epoch 3, iter = 900, loss = 0.374,                 5s per 100 iters
# time = 29m, epoch 3, iter = 1000, loss = 0.375,                 6s per 100 iters
# time = 29m, epoch 3, iter = 1100, loss = 0.371,                 5s per 100 iters
# time = 29m, epoch 3, iter = 1200, loss = 0.377,                 6s per 100 iters
# time = 29m, epoch 3, iter = 1300, loss = 0.371,                 5s per 100 iters
# time = 29m, epoch 3, iter = 1400, loss = 0.375,                 6s per 100 iters
# time = 29m, epoch 3, iter = 1500, loss = 0.371,                 5s per 100 iters
# time = 29m, epoch 3, iter = 1600, loss = 0.369,                 6s per 100 iters
# time = 29m, epoch 3, iter = 1700, loss = 0.374,                 5s per 100 iters
# time = 29m, epoch 3, iter = 1800, loss = 0.375,                 6s per 100 iters
# time = 29m, epoch 3, iter = 1900, loss = 0.370,                 6s per 100 iters
# time = 30m, epoch 3, iter = 2000, loss = 0.374,                 5s per 100 iters
# time = 30m, epoch 3, iter = 2100, loss = 0.373,                 6s per 100 iters
# time = 30m, epoch 3, iter = 2200, loss = 0.369,                 5s per 100 iters
# time = 30m, epoch 3, iter = 2300, loss = 0.369,                 6s per 100 iters
# time = 30m, epoch 3, iter = 2400, loss = 0.375,                 5s per 100 iters
# time = 30m, epoch 3, iter = 2500, loss = 0.371,                 6s per 100 iters
# time = 30m, epoch 3, iter = 2600, loss = 0.373,                 5s per 100 iters
# time = 30m, epoch 3, iter = 2700, loss = 0.377,                 6s per 100 iters
# time = 30m, epoch 3, iter = 2800, loss = 0.369,                 5s per 100 iters
# time = 30m, epoch 3, iter = 2900, loss = 0.371,                 6s per 100 iters
# time = 31m, epoch 3, iter = 3000, loss = 0.379,                 5s per 100 iters
# time = 31m, epoch 3, iter = 3100, loss = 0.369,                 5s per 100 iters
# time = 31m, epoch 3, iter = 3200, loss = 0.376,                 6s per 100 iters
# time = 31m, epoch 3, iter = 3300, loss = 0.373,                 5s per 100 iters
# time = 31m, epoch 3, iter = 3400, loss = 0.375,                 6s per 100 iters
# time = 31m, epoch 3, iter = 3500, loss = 0.372,                 5s per 100 iters
# time = 31m, epoch 3, iter = 3600, loss = 0.374,                 6s per 100 iters
# time = 31m, epoch 3, iter = 3700, loss = 0.374,                 5s per 100 iters
# time = 31m, epoch 3, iter = 3800, loss = 0.369,                 6s per 100 iters
# time = 31m, epoch 3, iter = 3900, loss = 0.373,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4000, loss = 0.372,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4100, loss = 0.372,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4200, loss = 0.371,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4300, loss = 0.373,                 6s per 100 iters
# time = 32m, epoch 3, iter = 4400, loss = 0.375,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4500, loss = 0.370,                 6s per 100 iters
# time = 32m, epoch 3, iter = 4600, loss = 0.371,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4700, loss = 0.371,                 6s per 100 iters
# time = 32m, epoch 3, iter = 4800, loss = 0.374,                 5s per 100 iters
# time = 32m, epoch 3, iter = 4900, loss = 0.371,                 6s per 100 iters
# time = 32m, epoch 3, iter = 5000, loss = 0.372,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5100, loss = 0.373,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5200, loss = 0.372,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5300, loss = 0.373,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5400, loss = 0.373,                 6s per 100 iters
# time = 33m, epoch 3, iter = 5500, loss = 0.371,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5600, loss = 0.371,                 6s per 100 iters
# time = 33m, epoch 3, iter = 5700, loss = 0.374,                 5s per 100 iters
# time = 33m, epoch 3, iter = 5800, loss = 0.369,                 6s per 100 iters
# time = 33m, epoch 3, iter = 5900, loss = 0.369,                 5s per 100 iters
# time = 33m, epoch 3, iter = 6000, loss = 0.372,                 6s per 100 iters
# time = 34m, epoch 3, iter = 6100, loss = 0.375,                 5s per 100 iters
# time = 34m, epoch 3, iter = 6200, loss = 0.372,                 5s per 100 iters
# time = 34m, epoch 3, iter = 6300, loss = 0.372,                 6s per 100 iters
# time = 34m, epoch 3, iter = 6400, loss = 0.370,                 5s per 100 iters
# time = 34m, epoch 3, iter = 6500, loss = 0.369,                 6s per 100 iters
# time = 34m, epoch 3, iter = 6600, loss = 0.373,                 5s per 100 iters
# time = 34m, epoch 3, iter = 6700, loss = 0.370,                 6s per 100 iters
# time = 34m, epoch 3, iter = 6800, loss = 0.369,                 5s per 100 iters
# time = 34m, epoch 3, iter = 6900, loss = 0.373,                 6s per 100 iters
# time = 34m, epoch 3, iter = 7000, loss = 0.370,                 5s per 100 iters
# time = 35m, epoch 3, iter = 7100, loss = 0.371,                 6s per 100 iters
# time = 35m, epoch 3, iter = 7200, loss = 0.368,                 5s per 100 iters
# time = 35m, epoch 3, iter = 7300, loss = 0.372,                 5s per 100 iters
# time = 35m, epoch 3, iter = 7400, loss = 0.372,                 6s per 100 iters
# time = 35m, epoch 3, iter = 7500, loss = 0.371,                 5s per 100 iters
# time = 35m, epoch 3, iter = 7600, loss = 0.373,                 6s per 100 iters
# time = 35m, epoch 3, iter = 7700, loss = 0.373,                 5s per 100 iters
# time = 35m, epoch 3, iter = 7800, loss = 0.371,                 6s per 100 iters
# time = 35m, epoch 3, iter = 7900, loss = 0.369,                 5s per 100 iters
# time = 35m, epoch 3, iter = 8000, loss = 0.370,                 6s per 100 iters
# time = 36m, epoch 3, iter = 8100, loss = 0.370,                 5s per 100 iters
# time = 36m, epoch 3, iter = 8200, loss = 0.370,                 5s per 100 iters
# time = 36m, epoch 3, iter = 8300, loss = 0.372,                 6s per 100 iters
# time = 36m, epoch 3, iter = 8400, loss = 0.368,                 5s per 100 iters
# time = 36m, epoch 3, iter = 8500, loss = 0.367,                 6s per 100 iters
# time = 36m, epoch 3, iter = 8600, loss = 0.368,                 5s per 100 iters
# time = 36m, epoch 3, iter = 8700, loss = 0.369,                 6s per 100 iters
# time = 36m, epoch 3, iter = 8800, loss = 0.370,                 5s per 100 iters
# time = 36m, epoch 3, iter = 8900, loss = 0.364,                 6s per 100 iters
# time = 36m, epoch 3, iter = 9000, loss = 0.368,                 5s per 100 iters
# time = 36m, epoch 3, iter = 9100, loss = 0.365,                 5s per 100 iters
# time = 37m, epoch 3, iter = 9200, loss = 0.364,                 5s per 100 iters
# time = 37m, epoch 3, iter = 9300, loss = 0.367,                 5s per 100 iters
# time = 37m, epoch 3, iter = 9400, loss = 0.367,                 6s per 100 iters
# time = 37m, epoch 3, iter = 9500, loss = 0.364,                 5s per 100 iters
# time = 37m, epoch 3, iter = 9600, loss = 0.367,                 6s per 100 iters
# time = 37m, epoch 3, iter = 9700, loss = 0.366,                 5s per 100 iters
# time = 37m, epoch 3, iter = 9800, loss = 0.364,                 6s per 100 iters
# time = 37m, epoch 3, iter = 9900, loss = 0.367,                 5s per 100 iters
# time = 37m, epoch 3, iter = 10000, loss = 0.362,                 6s per 100 iters
# time = 37m, epoch 3, iter = 10100, loss = 0.363,                 5s per 100 iters
# time = 38m, epoch 3, iter = 10200, loss = 0.363,                 5s per 100 iters
# time = 38m, epoch 3, iter = 10300, loss = 0.366,                 6s per 100 iters
# time = 38m, epoch 3, iter = 10400, loss = 0.367,                 5s per 100 iters
# time = 38m, epoch 3, iter = 10500, loss = 0.365,                 6s per 100 iters
# time = 38m, epoch 3, iter = 10600, loss = 0.364,                 5s per 100 iters
# time = 38m, epoch 3, iter = 10700, loss = 0.360,                 6s per 100 iters
# time = 38m, epoch 3, iter = 10800, loss = 0.366,                 5s per 100 iters
# time = 38m, epoch 3, iter = 10900, loss = 0.365,                 6s per 100 iters
# time = 38m, epoch 3, iter = 11000, loss = 0.361,                 5s per 100 iters
# time = 38m, epoch 3, iter = 11100, loss = 0.365,                 5s per 100 iters
# time = 39m, epoch 3, iter = 11200, loss = 0.363,                 5s per 100 iters
# time = 39m, epoch 3, iter = 11300, loss = 0.360,                 5s per 100 iters
# time = 39m, epoch 3, iter = 11400, loss = 0.361,                 6s per 100 iters
# time = 39m, epoch 3, iter = 11500, loss = 0.363,                 5s per 100 iters
# time = 39m, epoch 3, iter = 11600, loss = 0.359,                 6s per 100 iters
# time = 39m, epoch 3, iter = 11700, loss = 0.363,                 5s per 100 iters
# time = 39m, epoch 3, iter = 11800, loss = 0.363,                 6s per 100 iters
# time = 39m, epoch 3, iter = 11900, loss = 0.364,                 5s per 100 iters
# time = 39m, epoch 3, iter = 12000, loss = 0.364,                 5s per 100 iters
# time = 39m, epoch 3, iter = 12100, loss = 0.363,                 5s per 100 iters
# time = 39m, epoch 3, iter = 12200, loss = 0.362,                 5s per 100 iters
# time = 40m, epoch 3, iter = 12300, loss = 0.364,                 6s per 100 iters
# ...
# time = 64m, epoch 5, iter = 9300, loss = 0.358,                 6s per 100 iters
# time = 65m, epoch 5, iter = 9400, loss = 0.358,                 5s per 100 iters
# time = 65m, epoch 5, iter = 9500, loss = 0.358,                 6s per 100 iters
# time = 65m, epoch 5, iter = 9600, loss = 0.361,                 5s per 100 iters
# time = 65m, epoch 5, iter = 9700, loss = 0.357,                 6s per 100 iters
# time = 65m, epoch 5, iter = 9800, loss = 0.354,                 6s per 100 iters
# time = 65m, epoch 5, iter = 9900, loss = 0.361,                 6s per 100 iters
# time = 65m, epoch 5, iter = 10000, loss = 0.359,                 6s per 100 iters
# time = 65m, epoch 5, iter = 10100, loss = 0.359,                 6s per 100 iters
# time = 65m, epoch 5, iter = 10200, loss = 0.362,                 6s per 100 iters
# time = 66m, epoch 5, iter = 10300, loss = 0.358,                 5s per 100 iters
# time = 66m, epoch 5, iter = 10400, loss = 0.361,                 6s per 100 iters
# time = 66m, epoch 5, iter = 10500, loss = 0.358,                 5s per 100 iters
# time = 66m, epoch 5, iter = 10600, loss = 0.357,                 6s per 100 iters
# time = 66m, epoch 5, iter = 10700, loss = 0.357,                 5s per 100 iters
# time = 66m, epoch 5, iter = 10800, loss = 0.357,                 6s per 100 iters
# time = 66m, epoch 5, iter = 10900, loss = 0.361,                 5s per 100 iters
# time = 66m, epoch 5, iter = 11000, loss = 0.360,                 6s per 100 iters
# time = 66m, epoch 5, iter = 11100, loss = 0.359,                 5s per 100 iters
# time = 66m, epoch 5, iter = 11200, loss = 0.358,                 5s per 100 iters
# time = 67m, epoch 5, iter = 11300, loss = 0.361,                 6s per 100 iters
# time = 67m, epoch 5, iter = 11400, loss = 0.358,                 5s per 100 iters
# time = 67m, epoch 5, iter = 11500, loss = 0.356,                 6s per 100 iters
# time = 67m, epoch 5, iter = 11600, loss = 0.359,                 5s per 100 iters
# time = 67m, epoch 5, iter = 11700, loss = 0.356,                 6s per 100 iters
# time = 67m, epoch 5, iter = 11800, loss = 0.360,                 5s per 100 iters
# time = 67m, epoch 5, iter = 11900, loss = 0.359,                 6s per 100 iters
# time = 67m, epoch 5, iter = 12000, loss = 0.358,                 5s per 100 iters
# time = 67m, epoch 5, iter = 12100, loss = 0.359,                 6s per 100 iters
# time = 67m, epoch 5, iter = 12200, loss = 0.360,                 5s per 100 iters
# time = 67m, epoch 5, iter = 12300, loss = 0.362,                 5s per 100 iters
# time = 68m, epoch 5, iter = 12400, loss = 0.358,                 5s per 100 iters
# time = 68m, epoch 5, iter = 12500, loss = 0.359,                 5s per 100 iters
# time = 68m, epoch 5, iter = 12600, loss = 0.358,                 6s per 100 iters
# time = 68m, epoch 5, iter = 12700, loss = 0.359,                 5s per 100 iters
# time = 68m, epoch 5, iter = 12800, loss = 0.358,                 6s per 100 iters
# time = 68m, epoch 5, iter = 12900, loss = 0.357,                 5s per 100 iters
# time = 68m, epoch 5, iter = 13000, loss = 0.357,                 6s per 100 iters
# time = 68m, epoch 5, iter = 13100, loss = 0.357,                 5s per 100 iters
# Loss: 0.35671278948551993 Accuracy: 0.9565071428571429
# Precision: 0.9428109792575232 Recall: 0.9653866381662861 F1 Score: 0.9522999022344121
# AUC: 0.965386638166286
# Confusion Matrix:
# [[263234  17134]
#  [  1133 138499]]
# R-squared: 0.8040238972274851
# Mean Squared Error: 0.043492857142857146
# Log Loss: 1.5676414677595312
# time = 69m, epoch 6, iter = 100, loss = 0.356,                 63s per 100 iters
# time = 69m, epoch 6, iter = 200, loss = 0.360,                 5s per 100 iters
# time = 70m, epoch 6, iter = 300, loss = 0.360,                 6s per 100 iters
# time = 70m, epoch 6, iter = 400, loss = 0.360,                 5s per 100 iters
# time = 70m, epoch 6, iter = 500, loss = 0.356,                 6s per 100 iters
# time = 70m, epoch 6, iter = 600, loss = 0.358,                 5s per 100 iters
# time = 70m, epoch 6, iter = 700, loss = 0.361,                 6s per 100 iters
# time = 70m, epoch 6, iter = 800, loss = 0.358,                 5s per 100 iters
# time = 70m, epoch 6, iter = 900, loss = 0.363,                 6s per 100 iters
# time = 70m, epoch 6, iter = 1000, loss = 0.356,                 5s per 100 iters
# time = 70m, epoch 6, iter = 1100, loss = 0.361,                 6s per 100 iters
# time = 70m, epoch 6, iter = 1200, loss = 0.359,                 5s per 100 iters
# time = 71m, epoch 6, iter = 1300, loss = 0.357,                 5s per 100 iters
# time = 71m, epoch 6, iter = 1400, loss = 0.357,                 6s per 100 iters
# time = 71m, epoch 6, iter = 1500, loss = 0.361,                 5s per 100 iters
# time = 71m, epoch 6, iter = 1600, loss = 0.360,                 6s per 100 iters
# time = 71m, epoch 6, iter = 1700, loss = 0.360,                 5s per 100 iters
# time = 71m, epoch 6, iter = 1800, loss = 0.358,                 6s per 100 iters
# time = 71m, epoch 6, iter = 1900, loss = 0.359,                 5s per 100 iters
# time = 71m, epoch 6, iter = 2000, loss = 0.356,                 6s per 100 iters
# time = 71m, epoch 6, iter = 2100, loss = 0.360,                 5s per 100 iters
# time = 71m, epoch 6, iter = 2200, loss = 0.362,                 6s per 100 iters
# time = 72m, epoch 6, iter = 2300, loss = 0.359,                 5s per 100 iters
# time = 72m, epoch 6, iter = 2400, loss = 0.358,                 5s per 100 iters
# time = 72m, epoch 6, iter = 2500, loss = 0.358,                 6s per 100 iters
# time = 72m, epoch 6, iter = 2600, loss = 0.356,                 5s per 100 iters
# time = 72m, epoch 6, iter = 2700, loss = 0.358,                 6s per 100 iters
# time = 72m, epoch 6, iter = 2800, loss = 0.359,                 5s per 100 iters
# time = 72m, epoch 6, iter = 2900, loss = 0.361,                 6s per 100 iters
# time = 72m, epoch 6, iter = 3000, loss = 0.357,                 5s per 100 iters
# time = 72m, epoch 6, iter = 3100, loss = 0.359,                 6s per 100 iters
# time = 72m, epoch 6, iter = 3200, loss = 0.358,                 5s per 100 iters
# time = 72m, epoch 6, iter = 3300, loss = 0.357,                 6s per 100 iters
# time = 73m, epoch 6, iter = 3400, loss = 0.359,                 5s per 100 iters
# time = 73m, epoch 6, iter = 3500, loss = 0.357,                 5s per 100 iters
# time = 73m, epoch 6, iter = 3600, loss = 0.359,                 6s per 100 iters
# time = 73m, epoch 6, iter = 3700, loss = 0.357,                 5s per 100 iters
# time = 73m, epoch 6, iter = 3800, loss = 0.358,                 6s per 100 iters
# time = 73m, epoch 6, iter = 3900, loss = 0.358,                 5s per 100 iters
# time = 73m, epoch 6, iter = 4000, loss = 0.359,                 6s per 100 iters
# time = 73m, epoch 6, iter = 4100, loss = 0.358,                 5s per 100 iters
# time = 73m, epoch 6, iter = 4200, loss = 0.358,                 6s per 100 iters
# time = 73m, epoch 6, iter = 4300, loss = 0.357,                 5s per 100 iters
# time = 74m, epoch 6, iter = 4400, loss = 0.357,                 6s per 100 iters
# time = 74m, epoch 6, iter = 4500, loss = 0.357,                 5s per 100 iters
# time = 74m, epoch 6, iter = 4600, loss = 0.359,                 5s per 100 iters
# time = 74m, epoch 6, iter = 4700, loss = 0.357,                 6s per 100 iters
# time = 74m, epoch 6, iter = 4800, loss = 0.357,                 5s per 100 iters
# time = 74m, epoch 6, iter = 4900, loss = 0.360,                 6s per 100 iters
# time = 74m, epoch 6, iter = 5000, loss = 0.356,                 5s per 100 iters
# time = 74m, epoch 6, iter = 5100, loss = 0.358,                 6s per 100 iters
# time = 74m, epoch 6, iter = 5200, loss = 0.358,                 5s per 100 iters
# time = 74m, epoch 6, iter = 5300, loss = 0.356,                 6s per 100 iters
# time = 75m, epoch 6, iter = 5400, loss = 0.360,                 5s per 100 iters
# time = 75m, epoch 6, iter = 5500, loss = 0.357,                 6s per 100 iters
# time = 75m, epoch 6, iter = 5600, loss = 0.357,                 5s per 100 iters
# time = 75m, epoch 6, iter = 5700, loss = 0.361,                 5s per 100 iters
# time = 75m, epoch 6, iter = 5800, loss = 0.357,                 6s per 100 iters
# time = 75m, epoch 6, iter = 5900, loss = 0.356,                 5s per 100 iters
# time = 75m, epoch 6, iter = 6000, loss = 0.357,                 6s per 100 iters
# time = 75m, epoch 6, iter = 6100, loss = 0.355,                 5s per 100 iters
# time = 75m, epoch 6, iter = 6200, loss = 0.355,                 6s per 100 iters
# time = 75m, epoch 6, iter = 6300, loss = 0.356,                 5s per 100 iters
# time = 76m, epoch 6, iter = 6400, loss = 0.358,                 6s per 100 iters
# time = 76m, epoch 6, iter = 6500, loss = 0.361,                 5s per 100 iters
# time = 76m, epoch 6, iter = 6600, loss = 0.355,                 6s per 100 iters
# time = 76m, epoch 6, iter = 6700, loss = 0.357,                 5s per 100 iters
# time = 76m, epoch 6, iter = 6800, loss = 0.358,                 5s per 100 iters
# time = 76m, epoch 6, iter = 6900, loss = 0.357,                 6s per 100 iters
# time = 76m, epoch 6, iter = 7000, loss = 0.354,                 5s per 100 iters
# time = 76m, epoch 6, iter = 7100, loss = 0.361,                 6s per 100 iters
# time = 76m, epoch 6, iter = 7200, loss = 0.361,                 5s per 100 iters
# time = 76m, epoch 6, iter = 7300, loss = 0.357,                 6s per 100 iters
# time = 77m, epoch 6, iter = 7400, loss = 0.356,                 5s per 100 iters
# time = 77m, epoch 6, iter = 7500, loss = 0.357,                 6s per 100 iters
# time = 77m, epoch 6, iter = 7600, loss = 0.357,                 5s per 100 iters
# time = 77m, epoch 6, iter = 7700, loss = 0.355,                 6s per 100 iters
# time = 77m, epoch 6, iter = 7800, loss = 0.358,                 5s per 100 iters
# time = 77m, epoch 6, iter = 7900, loss = 0.357,                 6s per 100 iters
# time = 77m, epoch 6, iter = 8000, loss = 0.360,                 5s per 100 iters
# time = 77m, epoch 6, iter = 8100, loss = 0.360,                 5s per 100 iters
# time = 77m, epoch 6, iter = 8200, loss = 0.358,                 6s per 100 iters
# time = 77m, epoch 6, iter = 8300, loss = 0.358,                 5s per 100 iters
# time = 78m, epoch 6, iter = 8400, loss = 0.357,                 6s per 100 iters
# time = 78m, epoch 6, iter = 8500, loss = 0.357,                 5s per 100 iters
# time = 78m, epoch 6, iter = 8600, loss = 0.359,                 6s per 100 iters
# time = 78m, epoch 6, iter = 8700, loss = 0.360,                 5s per 100 iters
# time = 78m, epoch 6, iter = 8800, loss = 0.357,                 6s per 100 iters
# time = 78m, epoch 6, iter = 8900, loss = 0.359,                 5s per 100 iters
# time = 78m, epoch 6, iter = 9000, loss = 0.358,                 6s per 100 iters
# time = 78m, epoch 6, iter = 9100, loss = 0.360,                 5s per 100 iters
# time = 78m, epoch 6, iter = 9200, loss = 0.359,                 5s per 100 iters
# time = 78m, epoch 6, iter = 9300, loss = 0.357,                 6s per 100 iters
# time = 79m, epoch 6, iter = 9400, loss = 0.356,                 5s per 100 iters
# time = 79m, epoch 6, iter = 9500, loss = 0.358,                 6s per 100 iters
# time = 79m, epoch 6, iter = 9600, loss = 0.358,                 5s per 100 iters
# time = 79m, epoch 6, iter = 9700, loss = 0.358,                 6s per 100 iters
# time = 79m, epoch 6, iter = 9800, loss = 0.360,                 5s per 100 iters
# time = 79m, epoch 6, iter = 9900, loss = 0.358,                 6s per 100 iters
# time = 79m, epoch 6, iter = 10000, loss = 0.359,                 5s per 100 iters
# time = 79m, epoch 6, iter = 10100, loss = 0.359,                 6s per 100 iters
# time = 79m, epoch 6, iter = 10200, loss = 0.357,                 5s per 100 iters
# time = 79m, epoch 6, iter = 10300, loss = 0.355,                 6s per 100 iters
# time = 80m, epoch 6, iter = 10400, loss = 0.358,                 5s per 100 iters
# time = 80m, epoch 6, iter = 10500, loss = 0.357,                 6s per 100 iters
# time = 80m, epoch 6, iter = 10600, loss = 0.357,                 5s per 100 iters
# time = 80m, epoch 6, iter = 10700, loss = 0.355,                 5s per 100 iters
# time = 80m, epoch 6, iter = 10800, loss = 0.357,                 6s per 100 iters
# time = 80m, epoch 6, iter = 10900, loss = 0.361,                 5s per 100 iters
# time = 80m, epoch 6, iter = 11000, loss = 0.356,                 6s per 100 iters
# time = 80m, epoch 6, iter = 11100, loss = 0.356,                 5s per 100 iters
# time = 80m, epoch 6, iter = 11200, loss = 0.357,                 6s per 100 iters
# time = 80m, epoch 6, iter = 11300, loss = 0.355,                 5s per 100 iters
# time = 81m, epoch 6, iter = 11400, loss = 0.357,                 6s per 100 iters
# time = 81m, epoch 6, iter = 11500, loss = 0.357,                 5s per 100 iters
# time = 81m, epoch 6, iter = 11600, loss = 0.359,                 6s per 100 iters
# time = 81m, epoch 6, iter = 11700, loss = 0.355,                 5s per 100 iters
# time = 81m, epoch 6, iter = 11800, loss = 0.357,                 6s per 100 iters
# time = 81m, epoch 6, iter = 11900, loss = 0.355,                 5s per 100 iters
# time = 81m, epoch 6, iter = 12000, loss = 0.359,                 6s per 100 iters
# time = 81m, epoch 6, iter = 12100, loss = 0.360,                 6s per 100 iters
# time = 81m, epoch 6, iter = 12200, loss = 0.358,                 5s per 100 iters
# time = 81m, epoch 6, iter = 12300, loss = 0.360,                 6s per 100 iters
# time = 82m, epoch 6, iter = 12400, loss = 0.358,                 5s per 100 iters
# time = 82m, epoch 6, iter = 12500, loss = 0.358,                 6s per 100 iters
# time = 82m, epoch 6, iter = 12600, loss = 0.355,                 5s per 100 iters
# time = 82m, epoch 6, iter = 12700, loss = 0.360,                 6s per 100 iters
# time = 82m, epoch 6, iter = 12800, loss = 0.357,                 5s per 100 iters
# time = 82m, epoch 6, iter = 12900, loss = 0.357,                 6s per 100 iters
# time = 82m, epoch 6, iter = 13000, loss = 0.356,                 5s per 100 iters
# time = 82m, epoch 6, iter = 13100, loss = 0.353,                 6s per 100 iters
# Loss: 0.35720497881284236 Accuracy: 0.9559904761904762
# Precision: 0.9424518483459812 Recall: 0.9642590888796412 F1 Score: 0.9516876606697733
# AUC: 0.9642590888796412
# Confusion Matrix:
# [[263429  16939]
#  [  1545 138087]]
# R-squared: 0.8016958294384866
# Mean Squared Error: 0.04400952380952381
# Log Loss: 1.5862640220105757
# time = 83m, epoch 7, iter = 100, loss = 0.359,                 63s per 100 iters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-cc57afc00a9e> in <cell line: 31>()
#      29 optim = torch.optim.RAdam(model.parameters(), lr=learning_rate)
#      30
# ---> 31 train_model(model, optim, epochs, train_loader, val_loader, save_path)
#
# <ipython-input-29-7a851d4027a5> in train_model(model, opt, epochs, data, eval_data, path, print_every)
#     139             opt.zero_grad()
#     140             loss = F.cross_entropy(preds, trg)
# --> 141             loss.backward()
#     142             opt.step()
#     143
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     520                 inputs=inputs,
#     521             )
# --> 522         torch.autograd.backward(
#     523             self, gradient, retain_graph, create_graph, inputs=inputs
#     524         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     264     # some Python versions print out the first line of a multi-line function
#     265     # calls in the traceback and some print out the last line
# --> 266     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267         tensors,
#     268         grad_tensors_,
#
# KeyboardInterrupt:
